# %%
! python make_parameters.py --year 2018

# %% [markdown]
# For input string, the format is:
#
# Year_{year}/DataRun_{A,B,C,D)}/Bkg_{DY,tt, etc}/Sig_{ggH, VBF}
#
# Ie: Year_2018/DataRun_A,C/Bkg_TT/Sig_ , which states data_A, data_C and ttbar MC Background for year 2018, with no signal samples

# %%
# ! python run_prestage.py --year 2018 --chunksize 10000
# ! python run_prestage.py --year 2018 --chunksize 5000
# ! python run_prestage.py --year 2018 --chunksize 20000
# ! python run_prestage.py --year 2018 --chunksize 100000
# ! python -W ignore  run_prestage.py --chunksize 200000 --input_string "Year_2018/DataRun_A,B,C,D/Bkg_DY,TT/Sig_ggH,VBF"
# ! python run_prestage.py --chunksize 80000 --input_string "Year_2018/DataRun_A,C/Bkg_TT/Sig_"
# ! python run_prestage.py --chunksize 80000 --year 2018 --input_string "/DataRun_A,B,C,D/Bkg_DY,TT/Sig_ggH,VBF" --cluster True
# ! python run_prestage.py --chunksize 80000 --year 2018 --input_string "/DataRun_/Bkg_TT/Sig_ggH,VBF" --cluster True
# data_l = ['A', 'B', 'C', 'D']
data_l = []
# bkg_l = ['DY', 'TT',]
# sig_l = ['ggH', 'VBF']
bkg_l = ['DY',]
sig_l = []
! python run_prestage.py --chunksize 100000 --year 2018  --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)}
# ! python run_prestage.py --chunksize 5000 --year 2018  --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)}
# Out:
# Local scale Client created
# new dataset: dict_keys(['dy_M-100To200'])
#   0%|                                                     | 0/1 [00:00<?, ?it/s]sample_name: dy_M-100To200
# len(fnames): 128
# 2024-04-01 21:47:30,777 - distributed.core - INFO - Connection to tcp://127.0.0.1:44905 has been closed.
# 2024-04-01 21:47:31,754 - distributed.core - INFO - Connection to tcp://127.0.0.1:44905 has been closed.
# 100%|█████████████████████████████████████████████| 1/1 [00:30<00:00, 30.60s/it]
# Finished everything in 32.868 s.
# Total Events in files 219326954.
# 2024-04-01 21:47:33,484 - distributed.deploy.adaptive_core - INFO - Adaptive stop

# %%
# ! python run_prestage.py --change_fraction 0.1
# ! python run_prestage.py --change_fraction 0.001
# ! python run_prestage.py --change_fraction 0.0005
# ! python run_prestage.py --change_fraction 0.09 
# ! python run_prestage.py --change_fraction 0.25
# ! python run_prestage.py --change_fraction 1.0
! python run_prestage.py --change_fraction 0.3

# %%
# !  python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test/"
# ! nohup python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test_full/" &> output.log
# ! python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test_full/" 
# ! nohup python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test_full3/"  &> output.log
# ! python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/test_full3"
! python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/test_full2" 
# ! python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/manyBig"
# ! python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/singleBig"

# ! nohup python -W ignore run_stage1.py -y 2018 --use_gateway --save_path  "/depot/cms/users/yun79/results/stage1/test_validation_bigV2" 
# ! nohup python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/test_validation_bigV2" > output.log
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
#   0%|                                                    | 0/22 [00:00<?, ?it/s]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/0
# len(filelist): 108
# Finished file_idx 0 in 151.248 s.
# 2024-04-01 21:50:15,902 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:49208 remote=tcp://127.0.0.1:44147>: Stream is closed
#
#   5%|█▉                                         | 1/22 [02:40<56:08, 160.42s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/1
# len(filelist): 88
# Finished file_idx 1 in 193.559 s.
#
#   9%|███▋                                     | 2/22 [06:02<1:01:40, 185.02s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/2
# len(filelist): 93
# Finished file_idx 2 in 154.046 s.
# 2024-04-01 21:56:21,576 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37950 remote=tcp://127.0.0.1:41737>: Stream is closed
# 2024-04-01 21:56:21,578 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:37942 remote=tcp://127.0.0.1:41737>: Stream is closed
#
#  14%|█████▊                                     | 3/22 [08:46<55:29, 175.24s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/3
# len(filelist): 107
# Finished file_idx 3 in 182.308 s.
#
#  18%|███████▊                                   | 4/22 [11:58<54:36, 182.04s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/4
# len(filelist): 105
# Finished file_idx 4 in 138.952 s.
#
#  23%|█████████▊                                 | 5/22 [14:27<48:11, 170.11s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/5
# len(filelist): 108
# Finished file_idx 5 in 180.443 s.
#
#  27%|███████████▋                               | 6/22 [17:38<47:12, 177.04s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/6
# len(filelist): 108
# Finished file_idx 6 in 182.896 s.
# 2024-04-01 22:08:27,429 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:50560 remote=tcp://127.0.0.1:34621>: Stream is closed
# 2024-04-01 22:08:27,434 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:50548 remote=tcp://127.0.0.1:34621>: Stream is closed
#
#  32%|█████████████▋                             | 7/22 [20:52<45:38, 182.56s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/7
# len(filelist): 102
# Finished file_idx 7 in 160.517 s.
#
#  36%|███████████████▋                           | 8/22 [23:42<41:43, 178.82s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/8
# len(filelist): 105
# Finished file_idx 8 in 204.642 s.
#
#  41%|█████████████████▌                         | 9/22 [27:18<41:13, 190.29s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/9
# len(filelist): 108
# Finished file_idx 9 in 265.02 s.
#
#  45%|███████████████████                       | 10/22 [31:52<43:14, 216.22s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/10
# len(filelist): 108
# Finished file_idx 10 in 229.466 s.
#
#  50%|█████████████████████                     | 11/22 [35:52<40:58, 223.49s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/11
# len(filelist): 98
# Finished file_idx 11 in 167.458 s.
# 2024-04-01 22:26:24,624 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:55392 remote=tcp://127.0.0.1:34637>: Stream is closed
# 2024-04-01 22:26:24,625 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:55376 remote=tcp://127.0.0.1:34637>: Stream is closed
# 2024-04-01 22:26:24,627 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:55408 remote=tcp://127.0.0.1:34637>: Stream is closed
#
#  55%|██████████████████████▉                   | 12/22 [38:49<34:52, 209.25s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/12
# len(filelist): 108
# Finished file_idx 12 in 154.718 s.
#
#  59%|████████████████████████▊                 | 13/22 [41:34<29:23, 195.91s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/13
# len(filelist): 99
# Finished file_idx 13 in 155.468 s.
# 2024-04-01 22:31:54,770 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:47744 remote=tcp://127.0.0.1:37091>: Stream is closed
#
#  64%|██████████████████████████▋               | 14/22 [44:19<24:52, 186.55s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/14
# len(filelist): 108
# Finished file_idx 14 in 158.592 s.
# 2024-04-01 22:34:44,577 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:59210 remote=tcp://127.0.0.1:38109>: Stream is closed
# 2024-04-01 22:34:44,580 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:59216 remote=tcp://127.0.0.1:38109>: Stream is closed
#
#  68%|████████████████████████████▋             | 15/22 [47:09<21:10, 181.50s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/15
# len(filelist): 93
# Finished file_idx 15 in 181.556 s.
# 2024-04-01 22:37:55,586 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:48690 remote=tcp://127.0.0.1:45307>: Stream is closed
#
#  73%|██████████████████████████████▌           | 16/22 [50:20<18:26, 184.44s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/16
# len(filelist): 108
# Finished file_idx 16 in 194.996 s.
#
#  77%|████████████████████████████████▍         | 17/22 [53:46<15:54, 190.86s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/17
# len(filelist): 108
# Finished file_idx 17 in 182.433 s.
#
#  82%|██████████████████████████████████▎       | 18/22 [56:58<12:44, 191.20s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/18
# len(filelist): 108
# Finished file_idx 18 in 153.969 s.
#
#  86%|████████████████████████████████████▎     | 19/22 [59:43<09:10, 183.35s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/19
# len(filelist): 98
# Finished file_idx 19 in 150.037 s.
#
#  91%|████████████████████████████████████▎   | 20/22 [1:02:23<05:52, 176.34s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/20
# len(filelist): 101
# Finished file_idx 20 in 157.867 s.
#
#  95%|██████████████████████████████████████▏ | 21/22 [1:05:11<02:53, 173.73s/it]doing rochester!
# doing fsr!
# type(pt): ?? * var * ?float64
# total nmuons applied with fsrPhotons: dask.awkward<sum, type=Scalar, dtype=int64>
# type(eta): ?? * var * ?float64
# type(phi): ?? * var * ?float64
# type(mass): ?? * var * ?float64
# doing geofit
# sumWeights: 148609715516.8756
# do jec!
# doing zpt weight!
# doing musf!
# doing LHE!
# doing pdf!
# cross_section: 254.2
# integrated_lumi: 59970.0
# weight statistics: dict_keys(['genWeight', 'genWeight_normalization', 'xsec', 'lumi', 'l1prefiring', 'zpt_wgt', 'muID', 'muIso', 'muTrig', 'LHERen', 'LHEFac', 'pdf_2rms', 'jetpuid_wgt'])
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/dy_M-100To200/21
# len(filelist): 36
# Finished file_idx 21 in 158.788 s.
# 2024-04-01 22:55:34,249 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:54692 remote=tcp://127.0.0.1:38533>: Stream is closed
# 2024-04-01 22:55:34,253 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:54678 remote=tcp://127.0.0.1:38533>: Stream is closed
#
# 100%|████████████████████████████████████████| 22/22 [1:07:58<00:00, 171.88s/it]
#                                                                                 Finished sample dy_M-100To200 in 4078.598 s.
# 100%|█████████████████████████████████████████| 1/1 [1:07:58<00:00, 4078.60s/it]
# Finished everything in 4078.789 s.

# %% [markdown]
# Format of stage1 validation:
#
# Ratio_{Y or N}/LogY_{Y or N}/ShowLumi_{Y or N}/Status_{work or prelim}
#
# Ie: Ratio_Y/LogY_Y/ShowLumi_N/Status_work indicates to have Data/MC ratio plot on the bottom, plot in logarithmic scale, show the inntegrated luminosity value, and have "Work in progress" label

# %%
! python run_stage1_validation.py --fraction 0.001 --input_string "Ratio_Y/LogY_Y/ShowLumi_N/Status_work"
# ! python run_stage1_validation.py --fraction 0.01
# ! python run_stage1_validation.py --fraction 0.09 --input_string "Ratio_Y/LogY_Y/ShowLumi_N/Status_work"

# %%
! python validation_plotter.py --fraction 0.1
# Out:
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_A/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_B/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_C/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_D/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/dy_M-50/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/dy_M-100To200/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/ttjets_dl/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/ttjets_sl/*/*.parquet
# INFO: Now making plot for jet1_pt ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3
# INFO: Now making plot for njets ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3
# INFO: Now making plot for mu1_pt ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3
# INFO: Now making plot for mu2_pt ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3

# %%
# ! ls /depot/cms/users/yun79/results/stage1/test_full/f0_1/
! ls /depot/cms/users/yun79/results/stage1/test_full
# Out:
# f0_0005  f0_001  f0_1  f0_3  f1_0

# %%
import coffea
coffea.__version__
# Out:
# '2024.3.0'

# %%
! ls /depot/cms/users/yun79/results/stage1/test_validation_bigV2_3/2018/f1_0/
