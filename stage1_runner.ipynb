# %%
! python make_parameters.py --year 2018
# Out:
# make parameters key: muon_pt_cut
# make parameters key: muon_eta_cut
# make parameters key: muon_iso_cut
# make parameters key: muon_id
# make parameters key: muon_flags
# make parameters key: muon_leading_pt
# make parameters key: muon_trigmatch_iso
# make parameters key: muon_trigmatch_dr
# make parameters key: muon_trigmatch_id
# make parameters key: electron_pt_cut
# make parameters key: electron_eta_cut
# make parameters key: electron_id
# make parameters key: jet_pt_cut
# make parameters key: jet_eta_cut
# make parameters key: jet_id
# make parameters key: jet_puid
# make parameters key: min_dr_mu_jet
# make parameters key: btag_loose_wp
# make parameters key: btag_medium_wp
# make parameters key: softjet_dr2
# make parameters key: lumimask
# make parameters key: hlt
# make parameters key: roccor_file
# make parameters key: nnlops_file
# make parameters key: btag_sf_json
# make parameters key: btag_sf_csv
# make parameters key: pu_file_data
# make parameters key: pu_file_mc
# make parameters key: muSFFileList
# make parameters key: zpt_weights_file
# make parameters key: jetpuid_sf_file
# make parameters key: res_calib_path
# make parameters key: sths_names
# make parameters key: btag_systs
# make parameters key: event_flags
# make parameters key: do_l1prefiring_wgts
# make parameters key: n_pdf_variations
# make parameters key: dnn_max
# make parameters key: cross_sections
# make parameters key: integrated_lumis
# make parameters key: jec_parameters
# make parameters sub_jec_pars: {'jec_variations': ['Absolute_up', 'Absolute_down', 'Absolute2018_up', 'Absolute2018_down', 'BBEC1_up', 'BBEC1_down', 'BBEC12018_up', 'BBEC12018_down', 'EC2_up', 'EC2_down', 'EC22018_up', 'EC22018_down', 'HF_up', 'HF_down', 'HF2018_up', 'HF2018_down', 'RelativeBal_up', 'RelativeBal_down', 'RelativeSample2018_up', 'RelativeSample2018_down', 'FlavorQCD_up', 'FlavorQCD_down'], 'runs': ['A', 'B', 'C', 'D'], 'jec_levels_mc': ['L1FastJet', 'L2Relative', 'L3Absolute'], 'jec_levels_data': ['L1FastJet', 'L2Relative', 'L3Absolute', 'L2L3Residual'], 'jec_tags': 'Summer19UL18_V5_MC', 'jer_tags': 'Summer19UL18_JRV2_MC', 'jec_data_tags': {'Summer19UL18_RunA_V5_DATA': ['A'], 'Summer19UL18_RunB_V5_DATA': ['B'], 'Summer19UL18_RunC_V5_DATA': ['C'], 'Summer19UL18_RunD_V5_DATA': ['D']}, 'jer_variations': ['jer1_up', 'jer1_down', 'jer2_up', 'jer2_down', 'jer3_up', 'jer3_down', 'jer4_up', 'jer4_down', 'jer5_up', 'jer5_down', 'jer6_up', 'jer6_down']}
# make_parameters config_to_save:
#  {'muon_pt_cut': 20.0, 'muon_eta_cut': 2.4, 'muon_iso_cut': 0.25, 'muon_id': 'mediumId', 'muon_flags': [], 'muon_leading_pt': 26.0, 'muon_trigmatch_iso': 0.15, 'muon_trigmatch_dr': 0.1, 'muon_trigmatch_id': 'tightId', 'electron_pt_cut': 20.0, 'electron_eta_cut': 2.5, 'electron_id': 'mvaFall17V2Iso_WP90', 'jet_pt_cut': 25.0, 'jet_eta_cut': 4.7, 'jet_id': 'tight', 'jet_puid': 'loose', 'min_dr_mu_jet': 0.4, 'btag_loose_wp': 0.1208, 'btag_medium_wp': 0.4168, 'softjet_dr2': 0.16, 'lumimask': 'data/lumimasks/Cert_314472-325175_13TeV_Legacy2018_Collisions18_JSON.txt', 'hlt': ['IsoMu24'], 'roccor_file': 'data/roch_corr/RoccoR2018UL.txt', 'nnlops_file': 'data/NNLOPS_reweight.root', 'btag_sf_json': '/cvmfs/cms.cern.ch/rsync/cms-nanoAOD/jsonpog-integration/POG/BTV/2018_UL/btagging.json.gz', 'btag_sf_csv': 'data/btag/DeepCSV_106XUL18SF.csv', 'pu_file_data': 'data/pileup/puData2018_UL_withVar.root', 'pu_file_mc': 'data/pileup/mcPileup2018.root', 'muSFFileList': [{'id': ('data/muon_sf/year2018/MuonSF_Run2018_UL_ID.root', 'NUM_MediumID_DEN_TrackerMuons_abseta_pt'), 'iso': ('data/muon_sf/year2018/MuonSF_Run2018_UL_ISO.root', 'NUM_TightRelIso_DEN_MediumID_abseta_pt'), 'trig': ('data/muon_sf/mu2018/EfficienciesStudies_2018_trigger_EfficienciesAndSF_2018Data_BeforeMuonHLTUpdate.root', 'IsoMu24_PtEtaBins/efficienciesDATA/abseta_pt_DATA', 'IsoMu24_PtEtaBins/efficienciesMC/abseta_pt_MC'), 'scale': 0.14981586876464678}, {'id': ('data/muon_sf/year2018/MuonSF_Run2018_UL_ID.root', 'NUM_MediumID_DEN_TrackerMuons_abseta_pt'), 'iso': ('data/muon_sf/year2018/MuonSF_Run2018_UL_ISO.root', 'NUM_TightRelIso_DEN_MediumID_abseta_pt'), 'trig': ('data/muon_sf/mu2018/EfficienciesStudies_2018_trigger_EfficienciesAndSF_2018Data_AfterMuonHLTUpdate.root', 'IsoMu24_PtEtaBins/efficienciesDATA/abseta_pt_DATA', 'IsoMu24_PtEtaBins/efficienciesMC/abseta_pt_MC'), 'scale': 0.8501841312353532}], 'zpt_weights_file': 'data/zpt_weights.histo.json', 'jetpuid_sf_file': 'data/JetPUID_106XTraining_ULRun2_EffSFandUncties_v1.root', 'res_calib_path': 'data/res_calib/', 'sths_names': ['Yield', 'PTH200', 'Mjj60', 'Mjj120', 'Mjj350', 'Mjj700', 'Mjj1000', 'Mjj1500', 'PTH25', 'JET01'], 'btag_systs': ['jes', 'lf', 'hfstats1', 'hfstats2', 'cferr1', 'cferr2', 'hf', 'lfstats1', 'lfstats2'], 'event_flags': ['BadPFMuonFilter', 'EcalDeadCellTriggerPrimitiveFilter', 'HBHENoiseFilter', 'HBHENoiseIsoFilter', 'globalSuperTightHalo2016Filter', 'goodVertices', 'BadChargedCandidateFilter'], 'do_l1prefiring_wgts': False, 'n_pdf_variations': 33, 'dnn_max': 2.35, 'cross_sections': {'test': 6200.0, 'dy_M-50': 6195.8, 'dy_M-50_nocut': 6450.0, 'dy_M-100To200': 254.2, 'dy_0j': 4620.52, 'dy_1j': 922.5, 'dy_2j': 293.6, 'dy_m105_160_mg': 47.17, 'dy_m105_160_vbf_mg': {'2016': 1.77, '2017': 2.04, '2018': 2.03}, 'dy_m105_160_amc': 47.17, 'dy_m105_160_vbf_amc': {'2016': 1.77, '2017': 2.04, '2018': 2.03}, 'ewk_lljj_mll105_160': {'2016': 0.0508896, '2017': 0.0508896, '2018': 0.0508896}, 'ewk_lljj_mll105_160_py': {'2016': 0.0508896, '2017': 0.0508896, '2018': 0.0508896}, 'ewk_lljj_mll105_160_ptj0': {'2016': 0.07486, '2017': 0.0789, '2018': 0.0789}, 'ewk_lljj_mll50_mjj120': 1.719, 'ewk_lljj_mll105_160_py_dipole': {'2016': 0.07486, '2017': 0.0789, '2018': 0.0789}, 'ewk_m50': 3.998, 'st_top': 136.02, 'st_t_top': 3.4, 'st_t_antitop': 80.95, 'st_tw_top': 32.51, 'st_tw_antitop': 32.45, 'ttjets_dl': 86.65, 'ttjets_sl': 358.57, 'ww_2l2nu': 11.09, 'wz_3lnu': 5.22, 'wz_2l2q': 6.45, 'wz_1l1nu2q': 9.12, 'zz': 12.17, 'ttw': 0.2001, 'ttz': 0.2529, 'www': 0.2086, 'wwz': 0.1651, 'wzz': 0.05565, 'zzz': 0.01398, 'ggh_powheg': 0.01057, 'ggh_powhegPS': 0.01057, 'ggh_amcPS': 0.01057, 'ggh_amcPS_TuneCP5down': 0.01057, 'ggh_amcPS_TuneCP5up': 0.01057, 'ggh_amc': 0.01057, 'ggh_localTest': 0.01057, 'vbf': 0.0008210722, 'vbf_sync': 0.0008210722, 'vbf_powheg': 0.0008210722, 'vbf_powheg_herwig': 0.0008210722, 'vbf_powheg_dipole': 0.0008210722, 'vbf_powhegPS': 0.0008210722, 'vbf_amc_herwig': 0.0008210722, 'vbf_amcPS_TuneCP5down': 0.0008210722, 'vbf_amc ...

# %% [markdown]
# For input string, the format is:
#
# Year_{year}/DataRun_{A,B,C,D)}/Bkg_{DY,tt, etc}/Sig_{ggH, VBF}
#
# Ie: Year_2018/DataRun_A,C/Bkg_TT/Sig_ , which states data_A, data_C and ttbar MC Background for year 2018, with no signal samples

# %%
# ! python run_prestage.py --year 2018 --chunksize 10000
# ! python run_prestage.py --year 2018 --chunksize 5000
# ! python run_prestage.py --year 2018 --chunksize 20000
# ! python run_prestage.py --year 2018 --chunksize 100000
# ! python -W ignore  run_prestage.py --chunksize 200000 --input_string "Year_2018/DataRun_A,B,C,D/Bkg_DY,TT/Sig_ggH,VBF"
# ! python run_prestage.py --chunksize 80000 --input_string "Year_2018/DataRun_A,C/Bkg_TT/Sig_"
# ! python run_prestage.py --chunksize 80000 --year 2018 --input_string "/DataRun_A,B,C,D/Bkg_DY,TT/Sig_ggH,VBF" --cluster True
# ! python run_prestage.py --chunksize 80000 --year 2018 --input_string "/DataRun_/Bkg_TT/Sig_ggH,VBF" --cluster True
data_l = ['A', 'B', 'C', 'D']
# data_l = ['A', 'B', 'C']
bkg_l = ['DY', 'TT',]
sig_l = ['ggH', 'VBF']
! python run_prestage.py --chunksize 80000 --year 2018  --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)}
# Out:
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40929 instead
#   warnings.warn(
# Local scale Client created
# new dataset: dict_keys(['data_A', 'data_B', 'data_C', 'data_D', 'dy_M-50', 'dy_M-100To200', 'ttjets_dl', 'ttjets_sl', 'ggh_powheg', 'vbf_powheg'])
#   0%|                                                    | 0/10 [00:00<?, ?it/s]sample_name: data_A
# len(fnames): 92
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-03-03 01:22:57,268 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:22:57,268 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:22:58,287 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:22:58,287 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:23:20,606 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
#  10%|████▍                                       | 1/10 [00:48<07:14, 48.25s/it]sample_name: data_B
# len(fnames): 51
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
#  20%|████████▊                                   | 2/10 [01:07<04:10, 31.25s/it]sample_name: data_C
# len(fnames): 56
#  30%|█████████████▏                              | 3/10 [01:28<03:05, 26.54s/it]sample_name: data_D
# len(fnames): 194
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/coffea/nanoevents/methods/candidate.py:11: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# 2024-03-03 01:24:26,959 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,312 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,313 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,313 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,314 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,314 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,354 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,355 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,355 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,356 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,357 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,357 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:41,357 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:43,284 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:43,293 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:43,304 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:24:43,305 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
#  40%|█████████████████▌                          | 4/10 [02:06<03:05, 30.90s/it]sample_name: dy_M-50
# len(fnames): 204
# 2024-03-03 01:25:03,562 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:03,563 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:03,563 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:03,564 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:03,564 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:05,287 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:05,306 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:05,307 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:05,310 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:07,282 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:07,323 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:09,306 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:09,325 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fac4f3b2d40>, <Task finished name='Task-129279' coro=<BaseTCPListener._handle_stream() done, defined at /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py:653> exception=ValueError('invalid operation on non-started TCPListener')>)
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 659, in _handle_stream
#     logger.debug("Incoming connection from %r to %r", address, self.contact_address)
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 695, in contact_address
#     host, port = self.get_host_port()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 676, in get_host_port
#     self._check_started()
#   File "/depot/cms/kernels/coffea2024/lib/python3.10/site-packages/distributed/comm/tcp.py", line 651, in _check_started
#     raise ValueError("invalid operation on non-started TCPListener")
# ValueError: invalid operation on non-started TCPListener
# 2024-03-03 01:25:09,328 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:09,902 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44571'.
# 2024-03-03 01:25:09,904 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:44571'. Shutting down.
# 2024-03-03 01:25:12,525 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# 2024-03-03 01:25:13,420 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:35481'.
# 2024-03-03 01:25:13,422 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:35481'. Shutting down.
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/awkward/_singleton.py:47: ResourceWarning: unclosed <socket.socket fd=16, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('127.0.0.1', 33251), raddr=('127.0.0.1', 36184)>
#   return cls._ensure_instance()
#  50%|██████████████████████                      | 5/10 [02:35<02:32, 30.41s/it]2024-03-03 01:25:16,500 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# sample_name: dy_M-100To200
# len(fnames): 128
# 2024-03-03 01:25:19,273 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:35,303 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:35,307 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:36,301 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:36,309 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:36,309 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:37,308 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:37,311 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
#  60%|██████████████████████████▍                 | 6/10 [02:58<01:51, 27.82s/it]sample_name: ttjets_dl
# len(fnames): 155
# 2024-03-03 01:25:57,305 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:57,305 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:57,306 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:57,307 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:59,286 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:59,294 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:25:59,306 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:00,303 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:00,304 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:01,326 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:01,327 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:01,823 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43107'.
# 2024-03-03 01:26:01,824 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:43107'. Shutting down.
# 2024-03-03 01:26:04,525 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
#  70%|██████████████████████████████▊             | 7/10 [03:40<01:37, 32.59s/it]sample_name: ttjets_sl
# len(fnames): 391
# 2024-03-03 01:26:53,362 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,363 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,363 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,364 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,365 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,366 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,366 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,366 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,366 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:53,366 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:55,316 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:55,517 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:57,305 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:57,306 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:59,304 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:59,310 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
# 2024-03-03 01:26:59,329 - distributed.core - INFO - Connection to tcp://127.0.0.1:45297 has been closed.
#  80%|███████████████████████████████████▏        | 8/10 [04:20<01:09, 34.94s/it]sample_name: ggh_powheg
# len(fnames): 1
#  90%|███████████████████████████████████████▌    | 9/10 [04:22<00:24, 24.58s/it]sample_name: vbf_powheg
# len(fnames): 3
# 100%|███████████████████████████████████████████| 10/10 [04:25<00:00, 26.52s/it]
# Finished everything in 267.41 s.
# Total Events in files 2024686916.
# 2024-03-03 01:27:05,933 - distributed.deploy.adaptive_core - INFO - Adaptive stop

# %%
# ! python run_prestage.py --change_fraction 0.1
! python run_prestage.py --change_fraction 0.001
# ! python run_prestage.py --change_fraction 0.0005
# ! python run_prestage.py --change_fraction 0.09 
# ! python run_prestage.py --change_fraction 0.25
# ! python run_prestage.py --change_fraction 1.0
# ! python run_prestage.py --change_fraction 0.3
# Out:
# 100%|█████████████████████████████████████████| 10/10 [00:00<00:00, 4290.41it/s]
# Finished everything in 0.201 s.

# %%
# !  python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test/"
# ! nohup python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test_full/" &> output.log
# ! python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test_full/" 
# ! nohup python -W ignore run_stage1.py  --save_path "/depot/cms/users/yun79/results/stage1/test_full3/"  &> output.log
# ! python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/test_full3"
! python -W ignore run_stage1.py -y 2018 --save_path  "/depot/cms/users/yun79/results/stage1/test_full2"
# Out:
# Local scale Client created
#   0%|                                                     | 0/1 [00:00<?, ?it/s]smaller_files: [{'root://eos.cms.rcac.purdue.edu:1094///store/mc/RunIISummer20UL18NanoAODv9/VBFHToMuMu_M125_TuneCP5_withDipoleRecoil_13TeV-powheg-pythia8/NANOAODSIM/106X_upgrade2018_realistic_v16_L1v1-v1/2820000/083C985C-C112-3B46-A053-D72C1F83309D.root': {'object_path': 'Events', 'steps': [[0, 10044]], 'uuid': 'b16b5dea-fbcd-11ed-bae7-a2a0b8bcbeef'}}]
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]doing fsr!
# bad_idxs len: 239
# /depot/cms/kernels/coffea2024/lib/python3.10/site-packages/awkward/_nplikes/array_module.py:245: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*broadcasted_args, **(kwargs or {}))
# ak.num(muon_fsr): 239
# ak.num(events.Muon): 10044
# bad muon_fsr.pt_fsr: [[59.3, 63.3], [62.4, 63.1], [41.3, 45.8], ..., [48.8, 59.7], [73.7, 80.7]]
# bad muon_fsr.pt: [[59.3, 57.1], [62.4, 54.4], [41.3, 36.7], ..., [48.8, 42.8], [73.7, 71.5]]
# muon_fsr.matched_fsrPhoton.pt:
#  [[12.1, None], [None, 10.8], [16.7, ..., None], ..., [10.5, None], [35.7, None]]
# events b4 filter length: 10044
# sumWeights: 38767.655119895935
# events after filter length: 6486
# cross_section: 0.0008210722
# integrated_lumi: 59970.0
# weights: 6486
# save_path: /depot/cms/users/yun79/results/stage1/test_full2/2018/f1_0/vbf_powheg/0
# len(filelist): 1
#
# 100%|█████████████████████████████████████████████| 1/1 [00:36<00:00, 36.47s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:36<00:00, 36.47s/it]
# Finished everything in 40.489 s.

# %% [markdown]
# Format of stage1 validation:
#
# Ratio_{Y or N}/LogY_{Y or N}/ShowLumi_{Y or N}/Status_{work or prelim}
#
# Ie: Ratio_Y/LogY_Y/ShowLumi_N/Status_work indicates to have Data/MC ratio plot on the bottom, plot in logarithmic scale, show the inntegrated luminosity value, and have "Work in progress" label

# %%
! python run_stage1_validation.py --fraction 0.001 --input_string "Ratio_Y/LogY_Y/ShowLumi_N/Status_work"
# ! python run_stage1_validation.py --fraction 0.01
# ! python run_stage1_validation.py --fraction 0.09 --input_string "Ratio_Y/LogY_Y/ShowLumi_N/Status_work"

# %%
! python validation_plotter.py --fraction 0.1
# Out:
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_A/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_B/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_C/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/data_D/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/dy_M-50/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/dy_M-100To200/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/ttjets_dl/*/*.parquet
# full_load_path: /depot/cms/users/yun79/results/stage1/test_full/f0_1/ttjets_sl/*/*.parquet
# INFO: Now making plot for jet1_pt ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3
# INFO: Now making plot for njets ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3
# INFO: Now making plot for mu1_pt ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3
# INFO: Now making plot for mu2_pt ...
# colours: ['#5790fc', '#f89c20']
# labels: ['Top', 'DY']
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# flag
# flag2
# flag3

# %%
# ! ls /depot/cms/users/yun79/results/stage1/test_full/f0_1/
! ls /depot/cms/users/yun79/results/stage1/test_full
# Out:
# f0_0005  f0_1  f0_3  f1_0

# %%
import mplhep as hep
hep.__version__
# Out:
# '0.3.33'
