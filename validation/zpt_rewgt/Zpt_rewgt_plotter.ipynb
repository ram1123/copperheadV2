# %% [markdown]
# # Zpt re-wgt Validation
#
# This notebook shows the script to plot ZpT-rewgt validation code to verify that the Zpt-rewgt has been properly generated
#
# This script is inspired from validation_plotter_unified.py, and thus share a lot of same formatting.

# %%
data_l = ['A', 'B', 'C', 'D','E', 'F','H', 'G']
bkg_l = ['DY','TT','ST','VV','EWK', 'OTHER']
# bkg_l = ['DY','TT','ST','VV']
sig_l = ['ggH', 'VBF']

vars2plot = ['dimuon', 'mu', 'jet', 'dijet']
# vars2plot = ['mu']

lumi_dict = {
    "2018" : 59.83,
    "2017" : 41.48,
    "2016postVFP": 19.5,
    "2016preVFP": 16.81,
}
status = "Private_Work"
# region = "signal"
region = "z-peak"

# %%
"""
First we plot Zpt off stage1 plots to match AN-19-124 fig 4.3
"""
# label = "V2_Jan09_ForZptReWgt"
# label = "V2_Jan17_JecDefault_plotEveryonesZptWgt"
# label = "V2_Jan22_JecDefault_plotEveryonesZptWgt"
# label="UpdatedDY_100_200_CrossSection_24Feb"
# label="UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff/"
# label="UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff_newZptWgt25Mar2025"
# label="DYMiNNLO_jetpuidOff_newZptWgt25Mar2025"
label="DYMiNNLO_30Mar2025"

# year = "2018"
year = "2017"
# year = "2016postVFP"
# year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

category="nocat"
# category="ggh"

njet = -1

# zpt_name = "yes_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


# njet = 0

# zpt_name = "yes_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "no_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 1

# zpt_name = "yes_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "no_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


# njet = 2

# zpt_name = "yes_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "no_zpt"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
# Out:
# variables2plot: ['dimuon_mass_zpeak', 'dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'rpt_nominal', 'll_zstar_log_nominal', 'dimuon_rapidity', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'mu1_pt_over_mass', 'mu2_pt_over_mass', 'njets_nominal', 'jet1_pt_nominal', 'jet2_pt_nominal', 'jet1_eta_nominal', 'jet2_eta_nominal', 'jet1_phi_nominal', 'jet2_phi_nominal', 'jet1_qgl_nominal', 'jet2_qgl_nominal', 'jj_mass_nominal', 'jj_pt_nominal', 'jj_dEta_nominal', 'jj_dPhi_nominal', 'zeppenfeld_nominal', 'rpt_nominal', 'pt_centrality_nominal', 'nsoftjets2_nominal', 'htsoft2_nominal', 'nsoftjets5_nominal', 'htsoft5_nominal']
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'dy_M-100To200_MiNNLO', 'dy_M-50_MiNNLO', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'st_t_top', 'st_t_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'www', 'wwz', 'wzz', 'zzz', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_B/*/*.parquet
#   7%|██▉                                         | 2/30 [00:07<01:46,  3.79s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_C/*/*.parquet
#  10%|████▍                                       | 3/30 [00:18<03:01,  6.71s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_D/*/*.parquet
#  13%|█████▊                                      | 4/30 [00:23<02:34,  5.96s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_E/*/*.parquet
#  17%|███████▎                                    | 5/30 [00:32<03:01,  7.28s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_F/*/*.parquet
#  20%|████████▊                                   | 6/30 [00:47<03:50,  9.61s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_M-100To200/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_M-100To200/*.parquet Not available. Skipping
# loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process dy_M-100To200_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_M-100To200_MiNNLO/*/*.parquet
#  40%|█████████████████▏                         | 12/30 [00:48<00:47,  2.63s/it]loading process dy_M-50_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//dy_M-50_MiNNLO/*/*.parquet
#  43%|██████████████████▋                        | 13/30 [01:15<01:47,  6.32s/it]loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  47%|████████████████████                       | 14/30 [01:22<01:42,  6.38s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  50%|█████████████████████▌                     | 15/30 [01:36<02:00,  8.01s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  53%|██████████████████████▉                    | 16/30 [01:37<01:29,  6.37s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  57%|████████████████████████▎                  | 17/30 [01:37<01:04,  4.99s/it]loading process st_t_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//st_t_top/*/*.parquet
#  60%|█████████████████████████▊                 | 18/30 [01:45<01:06,  5.55s/it]loading process st_t_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//st_t_antitop/*/*.parquet
#  63%|███████████████████████████▏               | 19/30 [01:48<00:53,  4.87s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  67%|████████████████████████████▋              | 20/30 [01:49<00:37,  3.80s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  70%|██████████████████████████████             | 21/30 [01:50<00:27,  3.05s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  73%|███████████████████████████████▌           | 22/30 [01:52<00:23,  2.93s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//zz/*/*.parquet
#  77%|████████████████████████████████▉          | 23/30 [01:53<00:15,  2.18s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
#  80%|██████████████████████████████████▍        | 24/30 [01:54<00:10,  1.79s/it]loading process www..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//www/*/*.parquet
#  83%|███████████████████████████████████▊       | 25/30 [01:54<00:06,  1.35s/it]loading process wwz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//wwz/*/*.parquet
#  87%|█████████████████████████████████████▎     | 26/30 [01:54<00:04,  1.00s/it]loading process wzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//wzz/*/*.parquet
#  90%|██████████████████████████████████████▋    | 27/30 [01:54<00:02,  1.34it/s]loading process zzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//zzz/*/*.parquet
#  93%|████████████████████████████████████████▏  | 28/30 [01:55<00:01,  1.63it/s]loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//ggh_powhegPS/*/*.parquet
#  97%|█████████████████████████████████████████▌ | 29/30 [01:55<00:00,  1.68it/s]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2017/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 30/30 [01:56<00:00,  3.88s/it]
# finished loading parquet files!
#   0%|                                                    | 0/40 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_mass_zpeak in 47.845 s.
#   2%|█                                           | 1/40 [00:47<31:05, 47.85s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: dimuon_mass
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: dimuon_mass
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: dimuon_mass
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:110: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax_main.set_yscale('log')
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:110: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax_main.set_yscale('log')
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing dimuon_mass in 47.665 s.
#   5%|██▏                                         | 2/40 [01:35<30:14, 47.74s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: dimuon_pt
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: dimuon_pt
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_pt in 47.241 s.
#   8%|███▎                                        | 3/40 [02:22<29:17, 47.51s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: dimuon_eta
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: dimuon_eta
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: dimuon_eta
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: dimuon_eta
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: dimuon_eta
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: dimuon_eta
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: dimuon_eta
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: dimuon_eta
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_eta in 45.991 s.
#  10%|████▍                                       | 4/40 [03:08<28:08, 46.91s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_phi
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: dimuon_phi
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: dimuon_phi
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: dimuon_phi
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: dimuon_phi
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: dimuon_phi
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: dimuon_phi
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: dimuon_phi
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: dimuon_phi
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: dimuon_phi
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: dimuon_phi
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: dimuon_phi
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_phi in 46.207 s.
#  12%|█████▌                                      | 5/40 [03:54<27:13, 46.66s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: dimuon_cos_theta_cs
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_cos_theta_cs in 46.655 s.
#  15%|██████▌                                     | 6/40 [04:41<26:26, 46.66s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: dimuon_phi_cs
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# ...
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: htsoft2_nominal
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: htsoft2_nominal
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: htsoft2_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: htsoft2_nominal
# values is nan: False
# values is none: False
# VBF activated
# Finished processing htsoft2_nominal in 44.947 s.
#  95%|████████████████████████████████████████▊  | 38/40 [24:59<01:15, 37.99s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: nsoftjets5_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing nsoftjets5_nominal in 37.763 s.
#  98%|█████████████████████████████████████████▉ | 39/40 [25:37<00:37, 37.92s/it]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3556393
# category_selection data_B sum : 3283336
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7148119
# category_selection data_C sum : 6606004
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3176172
# category_selection data_D sum : 2934962
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6912125
# category_selection data_E sum : 6386556
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9934398
# category_selection data_F sum : 9164548
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1363020
# category_selection dy_M-100To200_MiNNLO sum : 765095
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 50954037
# category_selection dy_M-50_MiNNLO sum : 49648925
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 6616657
# category_selection ttjets_dl sum : 1893684
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 204906
# category_selection ttjets_sl sum : 87028
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 116203
# category_selection st_tw_top sum : 32624
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 114901
# category_selection st_tw_antitop sum : 32354
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22062
# category_selection st_t_top sum : 11063
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 11416
# category_selection st_t_antitop sum : 5772
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 340142
# category_selection ww_2l2nu sum : 106152
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 431404
# category_selection wz_3lnu sum : 346800
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2612230
# category_selection wz_2l2q sum : 2392706
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 78419
# category_selection zz sum : 72805
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1056606
# category_selection ewk_lljj_mll50_mjj120 sum : 971481
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1841
# category_selection www sum : 507
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 3448
# category_selection wwz sum : 2433
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 8467
# category_selection wzz sum : 7916
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 7716
# category_selection zzz sum : 7590
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 619978
# category_selection ggh_powhegPS sum : 13752
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1285788
# category_selection vbf_powheg_dipole sum : 27819
# var: htsoft5_nominal
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing htsoft5_nominal in 47.279 s.
# 100%|███████████████████████████████████████████| 40/40 [26:24<00:00, 39.61s/it]
# Finished in 1700.698 s.

# %%
region = "signal"
year="2018"
# category="ggh"
category="no_cat"

lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"
vars2plot = ['dimuon', "mu",]

keep_zpt_on = True # dummy value

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
# Out:
# variables2plot: ['dimuon_mass_zpeak', 'dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'rpt_nominal', 'll_zstar_log_nominal', 'dimuon_rapidity', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'dy_M-100To200_MiNNLO', 'dy_M-50_MiNNLO', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'st_t_top', 'st_t_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'www', 'wwz', 'wzz', 'zzz', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_A/*/*.parquet
#   3%|█▍                                          | 1/30 [00:11<05:37, 11.62s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_B/*/*.parquet
#   7%|██▉                                         | 2/30 [00:17<03:45,  8.05s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_C/*/*.parquet
#  10%|████▍                                       | 3/30 [00:22<03:01,  6.73s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_D/*/*.parquet
#  13%|█████▊                                      | 4/30 [00:46<05:55, 13.69s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet Not available. Skipping
# loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process dy_M-100To200_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200_MiNNLO/*/*.parquet
#  40%|█████████████████▏                         | 12/30 [00:48<00:47,  2.65s/it]loading process dy_M-50_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50_MiNNLO/*/*.parquet
#  43%|██████████████████▋                        | 13/30 [01:33<02:18,  8.12s/it]loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  47%|████████████████████                       | 14/30 [01:43<02:12,  8.31s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  50%|█████████████████████▌                     | 15/30 [01:55<02:16,  9.10s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  53%|██████████████████████▉                    | 16/30 [01:57<01:44,  7.47s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  57%|████████████████████████▎                  | 17/30 [01:58<01:17,  6.00s/it]loading process st_t_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_t_top/*/*.parquet
#  60%|█████████████████████████▊                 | 18/30 [02:05<01:15,  6.29s/it]loading process st_t_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_t_antitop/*/*.parquet
#  63%|███████████████████████████▏               | 19/30 [02:08<00:59,  5.41s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  67%|████████████████████████████▋              | 20/30 [02:09<00:43,  4.38s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  70%|██████████████████████████████             | 21/30 [02:10<00:30,  3.41s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  73%|███████████████████████████████▌           | 22/30 [02:13<00:25,  3.23s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//zz/*/*.parquet
#  77%|████████████████████████████████▉          | 23/30 [02:13<00:16,  2.42s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
#  80%|██████████████████████████████████▍        | 24/30 [02:15<00:12,  2.16s/it]loading process www..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//www/*/*.parquet
#  83%|███████████████████████████████████▊       | 25/30 [02:15<00:08,  1.66s/it]loading process wwz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wwz/*/*.parquet
#  87%|█████████████████████████████████████▎     | 26/30 [02:16<00:04,  1.24s/it]loading process wzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wzz/*/*.parquet
#  90%|██████████████████████████████████████▋    | 27/30 [02:16<00:02,  1.02it/s]loading process zzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//zzz/*/*.parquet
#  93%|████████████████████████████████████████▏  | 28/30 [02:16<00:01,  1.28it/s]loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ggh_powhegPS/*/*.parquet
#  97%|█████████████████████████████████████████▌ | 29/30 [02:17<00:00,  1.21it/s]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 30/30 [02:18<00:00,  4.63s/it]
# finished loading parquet files!
#   0%|                                                    | 0/20 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# Error: invalid category option!
#   0%|                                                    | 0/20 [00:02<?, ?it/s]
# Traceback (most recent call last):
#   File "/work/users/yun79/valerie/fork/copperheadV2/validation/zpt_rewgt/zpt_validation_plotter.py", line 542, in <module>
#     raise ValueError
# ValueError
# variables2plot: ['dimuon_mass_zpeak', 'dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'rpt_nominal', 'll_zstar_log_nominal', 'dimuon_rapidity', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'dy_M-100To200_MiNNLO', 'dy_M-50_MiNNLO', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'st_t_top', 'st_t_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'www', 'wwz', 'wzz', 'zzz', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_A/*/*.parquet
#   3%|█▍                                          | 1/30 [00:09<04:40,  9.68s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_B/*/*.parquet
#   7%|██▉                                         | 2/30 [00:14<03:06,  6.67s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_C/*/*.parquet
#  10%|████▍                                       | 3/30 [00:18<02:29,  5.55s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_D/*/*.parquet
#  13%|█████▊                                      | 4/30 [00:38<04:57, 11.45s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet Not available. Skipping
# loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process dy_M-100To200_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200_MiNNLO/*/*.parquet
#  40%|█████████████████▏                         | 12/30 [00:39<00:39,  2.17s/it]loading process dy_M-50_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50_MiNNLO/*/*.parquet
#  43%|██████████████████▋                        | 13/30 [01:16<01:50,  6.51s/it]loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  47%|████████████████████                       | 14/30 [01:23<01:46,  6.63s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  50%|█████████████████████▌                     | 15/30 [01:35<01:54,  7.64s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  53%|██████████████████████▉                    | 16/30 [01:36<01:26,  6.19s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  57%|████████████████████████▎                  | 17/30 [01:36<01:03,  4.92s/it]loading process st_t_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_t_top/*/*.parquet
#  60%|█████████████████████████▊                 | 18/30 [01:41<00:59,  5.00s/it]loading process st_t_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_t_antitop/*/*.parquet
#  63%|███████████████████████████▏               | 19/30 [01:45<00:50,  4.56s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  67%|████████████████████████████▋              | 20/30 [01:46<00:36,  3.60s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  70%|██████████████████████████████             | 21/30 [01:46<00:24,  2.76s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  73%|███████████████████████████████▌           | 22/30 [01:48<00:20,  2.54s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//zz/*/*.parquet
#  77%|████████████████████████████████▉          | 23/30 [01:49<00:13,  1.87s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
#  80%|██████████████████████████████████▍        | 24/30 [01:49<00:09,  1.59s/it]loading process www..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//www/*/*.parquet
#  83%|███████████████████████████████████▊       | 25/30 [01:50<00:05,  1.16s/it]loading process wwz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wwz/*/*.parquet
#  87%|█████████████████████████████████████▎     | 26/30 [01:50<00:03,  1.16it/s]loading process wzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wzz/*/*.parquet
#  90%|██████████████████████████████████████▋    | 27/30 [01:50<00:02,  1.49it/s]loading process zzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//zzz/*/*.parquet
#  93%|████████████████████████████████████████▏  | 28/30 [01:50<00:01,  1.90it/s]loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ggh_powhegPS/*/*.parquet
#  97%|█████████████████████████████████████████▌ | 29/30 [01:51<00:00,  1.75it/s]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 30/30 [01:51<00:00,  3.73s/it]
# finished loading parquet files!
#   0%|                                                    | 0/20 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# Error: invalid category option!
#   0%|                                                    | 0/20 [00:03<?, ?it/s]
# Traceback (most recent call last):
#   File "/work/users/yun79/valerie/fork/copperheadV2/validation/zpt_rewgt/zpt_validation_plotter.py", line 542, in <module>
#     raise ValueError
# ValueError
# variables2plot: ['dimuon_mass_zpeak', 'dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'rpt_nominal', 'll_zstar_log_nominal', 'dimuon_rapidity', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'dy_M-100To200_MiNNLO', 'dy_M-50_MiNNLO', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'st_t_top', 'st_t_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'www', 'wwz', 'wzz', 'zzz', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_A/*/*.parquet
#   3%|█▍                                          | 1/30 [00:10<05:05, 10.53s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_B/*/*.parquet
#   7%|██▉                                         | 2/30 [00:15<03:20,  7.18s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_C/*/*.parquet
#  10%|████▍                                       | 3/30 [00:20<02:44,  6.09s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_D/*/*.parquet
#  13%|█████▊                                      | 4/30 [00:41<05:12, 12.01s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet Not available. Skipping
# loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process dy_M-100To200_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200_MiNNLO/*/*.parquet
#  40%|█████████████████▏                         | 12/30 [00:42<00:40,  2.27s/it]loading process dy_M-50_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50_MiNNLO/*/*.parquet
#  43%|██████████████████▋                        | 13/30 [01:12<01:39,  5.85s/it]loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  47%|████████████████████                       | 14/30 [01:19<01:37,  6.08s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  50%|█████████████████████▌                     | 15/30 [01:32<01:48,  7.20s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  53%|██████████████████████▉                    | 16/30 [01:32<01:21,  5.86s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  57%|████████████████████████▎                  | 17/30 [01:33<01:00,  4.63s/it]loading process st_t_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_t_top/*/*.parquet
#  60%|█████████████████████████▊                 | 18/30 [01:39<00:59,  4.94s/it]loading process st_t_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//st_t_antitop/*/*.parquet
#  63%|███████████████████████████▏               | 19/30 [01:41<00:48,  4.40s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  67%|████████████████████████████▋              | 20/30 [01:42<00:34,  3.43s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  70%|██████████████████████████████             | 21/30 [01:43<00:23,  2.63s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  73%|███████████████████████████████▌           | 22/30 [01:44<00:18,  2.34s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//zz/*/*.parquet
#  77%|████████████████████████████████▉          | 23/30 [01:45<00:12,  1.85s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
#  80%|██████████████████████████████████▍        | 24/30 [01:46<00:09,  1.53s/it]loading process www..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//www/*/*.parquet
#  83%|███████████████████████████████████▊       | 25/30 [01:46<00:05,  1.12s/it]loading process wwz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wwz/*/*.parquet
#  87%|█████████████████████████████████████▎     | 26/30 [01:46<00:03,  1.21it/s]loading process wzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//wzz/*/*.parquet
#  90%|██████████████████████████████████████▋    | 27/30 [01:46<00:01,  1.51it/s]loading process zzz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//zzz/*/*.parquet
#  93%|████████████████████████████████████████▏  | 28/30 [01:47<00:01,  1.85it/s]loading process ggh_powhegPS..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//ggh_powhegPS/*/*.parquet
#  97%|█████████████████████████████████████████▌ | 29/30 [01:47<00:00,  1.75it/s]loading process vbf_powheg_dipole..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//vbf_powheg_dipole/*/*.parquet
# 100%|███████████████████████████████████████████| 30/30 [01:48<00:00,  3.61s/it]
# finished loading parquet files!
#   0%|                                                    | 0/20 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 10573606
# category_selection data_A sum : 105227
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5361647
# category_selection data_B sum : 53698
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5249977
# category_selection data_C sum : 51793
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 24319299
# category_selection data_D sum : 244188
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1967995
# category_selection dy_M-100To200_MiNNLO sum : 455742
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 76320043
# category_selection dy_M-50_MiNNLO sum : 5893
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9290715
# category_selection ttjets_dl sum : 22831
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 296796
# category_selection ttjets_sl sum : 142
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 158926
# category_selection st_tw_top sum : 1943
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 153471
# category_selection st_tw_antitop sum : 1865
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 33380
# category_selection st_t_top sum : 157
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 17553
# category_selection st_t_antitop sum : 78
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 501801
# category_selection ww_2l2nu sum : 47430
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 422198
# category_selection wz_3lnu sum : 4728
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2632998
# category_selection wz_2l2q sum : 1479
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 105355
# category_selection zz sum : 418
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1420861
# category_selection ewk_lljj_mll50_mjj120 sum : 500
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2721
# category_selection www sum : 38
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 4774
# category_selection wwz sum : 35
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 8742
# category_selection wzz sum : 8
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 11312
# category_selection zzz sum : 1
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 626890
# category_selection ggh_powhegPS sum : 306909
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1297551
# category_selection vbf_powheg_dipole sum : 67097
# var: dimuon_mass_zpeak
# values is nan: False
# values is none: False
# VBF activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:110: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax_main.set_yscale('log')
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:110: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax_main.set_yscale('log')
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing dimuon_mass_zpeak in 46.854 s.
#   5%|██▏                                         | 1/20 [00:46<14:50, 46.85s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 10573606
# category_selection data_A sum : 105227
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5361647
# category_selection data_B sum : 53698
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5249977
# category_selection data_C sum : 51793
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 24319299
# category_selection data_D sum : 244188
# var: dimuon_mass
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1967995
# category_selection dy_M-100To200_MiNNLO sum : 455742
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 76320043
# category_selection dy_M-50_MiNNLO sum : 5893
# var: dimuon_mass
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9290715
# category_selection ttjets_dl sum : 22831
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 296796
# category_selection ttjets_sl sum : 142
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 158926
# category_selection st_tw_top sum : 1943
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 153471
# category_selection st_tw_antitop sum : 1865
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 33380
# category_selection st_t_top sum : 157
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 17553
# category_selection st_t_antitop sum : 78
# var: dimuon_mass
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 501801
# category_selection ww_2l2nu sum : 47430
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 422198
# category_selection wz_3lnu sum : 4728
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2632998
# category_selection wz_2l2q sum : 1479
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 105355
# category_selection zz sum : 418
# var: dimuon_mass
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1420861
# category_selection ewk_lljj_mll50_mjj120 sum : 500
# var: dimuon_mass
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2721
# category_selection www sum : 38
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 4774
# category_selection wwz sum : 35
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 8742
# category_selection wzz sum : 8
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 11312
# category_selection zzz sum : 1
# var: dimuon_mass
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 626890
# category_selection ggh_powhegPS sum : 306909
# var: dimuon_mass
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1297551
# category_selection vbf_powheg_dipole sum : 67097
# var: dimuon_mass
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_mass in 39.986 s.
#  10%|████▍                                       | 2/20 [01:26<12:50, 42.81s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 10573606
# category_selection data_A sum : 105227
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5361647
# category_selection data_B sum : 53698
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5249977
# category_selection data_C sum : 51793
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 24319299
# category_selection data_D sum : 244188
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1967995
# category_selection dy_M-100To200_MiNNLO sum : 455742
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 76320043
# category_selection dy_M-50_MiNNLO sum : 5893
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9290715
# category_selection ttjets_dl sum : 22831
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 296796
# category_selection ttjets_sl sum : 142
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 158926
# category_selection st_tw_top sum : 1943
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 153471
# category_selection st_tw_antitop sum : 1865
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 33380
# category_selection st_t_top sum : 157
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 17553
# category_selection st_t_antitop sum : 78
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 501801
# category_selection ww_2l2nu sum : 47430
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 422198
# category_selection wz_3lnu sum : 4728
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2632998
# category_selection wz_2l2q sum : 1479
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 105355
# category_selection zz sum : 418
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1420861
# category_selection ewk_lljj_mll50_mjj120 sum : 500
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2721
# category_selection www sum : 38
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 4774
# category_selection wwz sum : 35
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 8742
# category_selection wzz sum : 8
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 11312
# category_selection zzz sum : 1
# var: dimuon_pt
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 626890
# category_selection ggh_powhegPS sum : 306909
# var: dimuon_pt
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1297551
# category_selection vbf_powheg_dipole sum : 67097
# var: dimuon_pt
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_pt in 41.031 s.
#  15%|██████▌                                     | 3/20 [02:07<11:54, 42.00s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 10573606
# category_selection data_A sum : 105227
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5361647
# category_selection data_B sum : 53698
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5249977
# category_selection data_C sum : 51793
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 24319299
# category_selection data_D sum : 244188
# var: dimuon_eta
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1967995
# category_selection dy_M-100To200_MiNNLO sum : 455742
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 76320043
# category_selection dy_M-50_MiNNLO sum : 5893
# var: dimuon_eta
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9290715
# category_selection ttjets_dl sum : 22831
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 296796
# category_selection ttjets_sl sum : 142
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 158926
# category_selection st_tw_top sum : 1943
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 153471
# category_selection st_tw_antitop sum : 1865
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 33380
# category_selection st_t_top sum : 157
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 17553
# category_selection st_t_antitop sum : 78
# var: dimuon_eta
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# ...
# category_selection length: 17553
# category_selection st_t_antitop sum : 298
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 501801
# category_selection ww_2l2nu sum : 27788
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 422198
# category_selection wz_3lnu sum : 7438
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2632998
# category_selection wz_2l2q sum : 10410
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 105355
# category_selection zz sum : 650
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1420861
# category_selection ewk_lljj_mll50_mjj120 sum : 5424
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2721
# category_selection www sum : 109
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 4774
# category_selection wwz sum : 71
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 8742
# category_selection wzz sum : 21
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 11312
# category_selection zzz sum : 4
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 626890
# category_selection ggh_powhegPS sum : 191816
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1297551
# category_selection vbf_powheg_dipole sum : 379980
# var: dimuon_rapidity
# values is nan: False
# values is none: False
# VBF activated
# Finished processing dimuon_rapidity in 50.315 s.
#  60%|█████████████████████████▊                 | 12/20 [09:49<06:36, 49.62s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 10573606
# category_selection data_A sum : 43903
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 5361647
# category_selection data_B sum : 22103
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 5249977
# category_selection data_C sum : 21930
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 24319299
# category_selection data_D sum : 98486
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1967995
# category_selection dy_M-100To200_MiNNLO sum : 161964
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 76320043
# category_selection dy_M-50_MiNNLO sum : 2472
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 9290715
# category_selection ttjets_dl sum : 220250
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 296796
# category_selection ttjets_sl sum : 1340
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 158926
# category_selection st_tw_top sum : 10944
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 153471
# category_selection st_tw_antitop sum : 10403
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_t_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 33380
# category_selection st_t_top sum : 481
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_t_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 17553
# category_selection st_t_antitop sum : 298
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 501801
# category_selection ww_2l2nu sum : 27788
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 422198
# category_selection wz_3lnu sum : 7438
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2632998
# category_selection wz_2l2q sum : 10410
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 105355
# category_selection zz sum : 650
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1420861
# category_selection ewk_lljj_mll50_mjj120 sum : 5424
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# process: www
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2721
# category_selection www sum : 109
# var: mu1_pt
# values is nan: False
# values is none: False
# other activated
# process: wwz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 4774
# category_selection wwz sum : 71
# var: mu1_pt
# values is nan: False
# values is none: False
# other activated
# process: wzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 8742
# category_selection wzz sum : 21
# var: mu1_pt
# values is nan: False
# values is none: False
# other activated
# process: zzz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 11312
# category_selection zzz sum : 4
# var: mu1_pt
# values is nan: False
# values is none: False
# other activated
# process: ggh_powhegPS
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 626890
# category_selection ggh_powhegPS sum : 191816
# var: mu1_pt
# values is nan: False
# values is none: False
# ggH activated
# process: vbf_powheg_dipole
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1297551
# category_selection vbf_powheg_dipole sum : 379980
# var: mu1_pt
# values is nan: False
# values is none: False
# VBF activated
# Finished processing mu1_pt in 56.427 s.
#  65%|███████████████████████████▉               | 13/20 [10:46<06:01, 51.68s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 10573606
# category_selection data_A sum : 43903
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 5361647
# category_selection data_B sum : 22103
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 5249977
# category_selection data_C sum : 21930
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 24319299
# category_selection data_D sum : 98486
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# skipping dy_M-100To200
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: dy_M-100To200_MiNNLO
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1967995
# category_selection dy_M-100To200_MiNNLO sum : 161964
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-50_MiNNLO
# is_data: False
# variables2plot: ['dimuon_mass_zpeak', 'dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'rpt_nominal', 'll_zstar_log_nominal', 'dimuon_rapidity', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'dy_M-100To200_MiNNLO', 'dy_M-50_MiNNLO', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'st_t_top', 'st_t_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'www', 'wwz', 'wzz', 'zzz', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_A/*/*.parquet
#   3%|█▍                                          | 1/30 [00:12<06:05, 12.62s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_B/*/*.parquet
#   7%|██▉                                         | 2/30 [00:17<03:50,  8.23s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_C/*/*.parquet
#  10%|████▍                                       | 3/30 [00:22<03:03,  6.79s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_D/*/*.parquet
#  13%|█████▊                                      | 4/30 [00:47<06:04, 14.03s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200/*.parquet Not available. Skipping
# loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process dy_M-100To200_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-100To200_MiNNLO/*/*.parquet
#  40%|█████████████████▏                         | 12/30 [00:49<00:49,  2.73s/it]loading process dy_M-50_MiNNLO..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//dy_M-50_MiNNLO/*/*.parquet
# variables2plot: ['dimuon_mass_zpeak', 'dimuon_mass', 'dimuon_pt', 'dimuon_eta', 'dimuon_phi', 'dimuon_cos_theta_cs', 'dimuon_phi_cs', 'mmj_min_dPhi_nominal', 'mmj_min_dEta_nominal', 'rpt_nominal', 'll_zstar_log_nominal', 'dimuon_rapidity', 'mu1_pt', 'mu2_pt', 'mu1_eta', 'mu2_eta', 'mu1_phi', 'mu2_phi', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'dy_M-100To200_MiNNLO', 'dy_M-50_MiNNLO', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'st_t_top', 'st_t_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120', 'www', 'wwz', 'wzz', 'zzz', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_A/*/*.parquet
#   3%|█▍                                          | 1/30 [00:11<05:29, 11.37s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_B/*/*.parquet
#   7%|██▉                                         | 2/30 [00:16<03:35,  7.71s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_C/*/*.parquet
#  10%|████▍                                       | 3/30 [00:21<02:53,  6.42s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/DYMiNNLO_30Mar2025/stage1_output/2018/f1_0//data_D/*/*.parquet

# %%
year = "2016postVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# %%
year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
