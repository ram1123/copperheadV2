# %% [markdown]
# # Zpt re-wgt Validation
#
# This notebook shows the script to plot ZpT-rewgt validation code to verify that the Zpt-rewgt has been properly generated
#
# This script is inspired from validation_plotter_unified.py, and thus share a lot of same formatting.

# %%
data_l = ['A', 'B', 'C', 'D','E', 'F','H', 'G']
bkg_l = ['DY','TT','ST','VV','EWK']
sig_l = ['ggH', 'VBF']

vars2plot = ['dimuon']

lumi_dict = {
    "2018" : 59.97,
    "2017" : 41.5,
    "2016postVFP": 19.5,
    "2016preVFP": 16.8,
}
status = "Private_Work"
region = "signal"

# %%
label = "V2_Jan11_NewZptReWgt"
year = "2018"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "../../src/lib/histogram/plot_settings_vbfCat_MVA_input.json"

# %%
"""
Zpt On
"""

keep_zpt_on = True

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36993 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██                                          | 1/21 [00:04<01:21,  4.05s/it]loading process data_B..
# ...

# %%
"""
Zpt Off
"""

keep_zpt_on = False

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41263 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██                                          | 1/21 [00:04<01:21,  4.09s/it]loading process data_B..
# ...

# %%
label = "V2_Jan11_NewZptReWgt"
year = "2017"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "../../src/lib/histogram/plot_settings_vbfCat_MVA_input.json"

# %%
"""
Zpt On
"""

keep_zpt_on = True

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38755 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# ...

# %%
"""
Zpt Off
"""

keep_zpt_on = False

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42187 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# ...

# %%
label = "V2_Jan11_NewZptReWgt"
year = "2016postVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "../../src/lib/histogram/plot_settings_vbfCat_MVA_input.json"

# %%
"""
Zpt On
"""

keep_zpt_on = True

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}

"""
Zpt Off
"""

keep_zpt_on = False

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41969 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2016postVFP/f1_0//data_A/*.parquet
# ...

# %%
label = "V2_Jan11_NewZptReWgt"
year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "../../src/lib/histogram/plot_settings_vbfCat_MVA_input.json"

# %%
"""
Zpt On
"""

keep_zpt_on = True

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}

"""
Zpt Off
"""

keep_zpt_on = False

njet = 0
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 1
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
njet = 2
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet}
# Out:
# variables2plot: ['dimuon_mass', 'dimuon_pt']
# /depot/cms/kernels/root632/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39643 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll105_160_ptj0', 'ggh_powhegPS', 'vbf_powheg_dipole']
#   0%|                                                    | 0/21 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan11_NewZptReWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# ...
