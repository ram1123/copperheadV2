# %% [markdown]
# # Zpt re-wgt Validation
#
# This notebook shows the script to plot ZpT-rewgt validation code to verify that the Zpt-rewgt has been properly generated
#
# This script is inspired from validation_plotter_unified.py, and thus share a lot of same formatting.

# %%
data_l = ['A', 'B', 'C', 'D','E', 'F','H', 'G']
bkg_l = ['DY','TT','ST','VV','EWK']
# bkg_l = ['DY','TT','ST','VV']
# sig_l = ['ggH', 'VBF']
sig_l = []

vars2plot = ['dimuon']

lumi_dict = {
    "2018" : 59.83,
    "2017" : 41.48,
    "2016postVFP": 19.5,
    "2016preVFP": 16.81,
}
status = "Private_Work"
region = "signal"

# %%
"""
First we plot Zpt off stage1 plots to match AN-19-124 fig 4.3
"""
# label = "V2_Jan09_ForZptReWgt"
# label = "V2_Jan17_JecDefault_plotEveryonesZptWgt"
label = "V2_Jan22_JecDefault_plotEveryonesZptWgt"

year = "2018"
# year = "2017"
# year = "2016postVFP"
# year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value


njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# %%
"""
First we plot Zpt off stage1 plots to match AN-19-124 fig 4.3
"""
# label = "V2_Jan09_ForZptReWgt"
# label = "V2_Jan17_JecDefault_plotEveryonesZptWgt"
label = "V2_Jan22_JecDefault_plotEveryonesZptWgt"

year = "2017"
# year = "2016postVFP"
# year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value


# njet = -1

# # zpt_name = "zpt_weight_mine_nbins50"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 0

zpt_name = "zpt_weight_mine_nbins50"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "zpt_weight_mine_nbins100"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_dmitry"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "zpt_weight_valerie"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "zpt_weight_mine_nbins50"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "zpt_weight_mine_nbins100"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_dmitry"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "zpt_weight_valerie"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 2

zpt_name = "zpt_weight_mine_nbins50"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "zpt_weight_mine_nbins100"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_dmitry"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "zpt_weight_valerie"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
# Out:
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46577 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:03<00:32,  1.81s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:07<00:45,  2.68s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:09<00:37,  2.34s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:13<00:46,  3.12s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:19<00:56,  4.01s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:34<00:38,  3.83s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:40<00:28,  3.58s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:46<00:27,  3.91s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:46<00:19,  3.22s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:47<00:12,  2.59s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:47<00:08,  2.08s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:48<00:05,  1.70s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:50<00:03,  1.94s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:51<00:01,  1.48s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:52<00:00,  2.60s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3534725
# category_selection data_B sum : 37545
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 7092124
# category_selection data_C sum : 75689
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3151971
# category_selection data_D sum : 33529
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 6858263
# category_selection data_E sum : 71010
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9861751
# category_selection data_F sum : 100876
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins50!
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 29651185
# category_selection dy_M-100To200 sum : 5318578
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 6580175
# category_selection ttjets_dl sum : 14504
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 199496
# category_selection ttjets_sl sum : 96
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 115607
# category_selection st_tw_top sum : 1386
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 114306
# category_selection st_tw_antitop sum : 1307
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 337789
# category_selection ww_2l2nu sum : 32926
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 425164
# category_selection wz_3lnu sum : 4907
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2600161
# category_selection wz_2l2q sum : 1431
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 78009
# category_selection zz sum : 322
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1052640
# category_selection ewk_lljj_mll50_mjj120 sum : 339
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 37.701 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:37<00:00, 37.70s/it]
# Finished in 89.795 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45843 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
#   5%|██▏                                         | 1/20 [00:00<00:02,  8.98it/s]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:19,  1.07s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:04<00:27,  1.62s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:05<00:26,  1.63s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:07<00:26,  1.78s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:10<00:30,  2.20s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
#  35%|███████████████▍                            | 7/20 [00:10<00:19,  1.52s/it]loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:18<00:20,  2.08s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:20<00:13,  1.68s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:24<00:14,  2.10s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:24<00:10,  1.69s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:24<00:06,  1.33s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:24<00:04,  1.07s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:25<00:02,  1.19it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:25<00:01,  1.32it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:25<00:00,  1.30s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3534725
# category_selection data_B sum : 37545
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 7092124
# category_selection data_C sum : 75689
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3151971
# category_selection data_D sum : 33529
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 6858263
# category_selection data_E sum : 71010
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9861751
# category_selection data_F sum : 100876
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins100!
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 29651185
# category_selection dy_M-100To200 sum : 5318578
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 6580175
# category_selection ttjets_dl sum : 14504
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 199496
# category_selection ttjets_sl sum : 96
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 115607
# category_selection st_tw_top sum : 1386
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 114306
# category_selection st_tw_antitop sum : 1307
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 337789
# category_selection ww_2l2nu sum : 32926
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 425164
# category_selection wz_3lnu sum : 4907
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2600161
# category_selection wz_2l2q sum : 1431
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 78009
# category_selection zz sum : 322
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1052640
# category_selection ewk_lljj_mll50_mjj120 sum : 339
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 32.107 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:32<00:00, 32.11s/it]
# Finished in 58.07 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41007 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:02<00:19,  1.06s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:04<00:27,  1.64s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:05<00:22,  1.40s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:07<00:25,  1.72s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:11<00:32,  2.30s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:19<00:20,  2.05s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:20<00:13,  1.69s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:25<00:14,  2.14s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:25<00:10,  1.75s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:25<00:07,  1.40s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:25<00:04,  1.12s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:26<00:02,  1.11it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:26<00:01,  1.19it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:27<00:00,  1.35s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3534725
# category_selection data_B sum : 37545
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 7092124
# category_selection data_C sum : 75689
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3151971
# category_selection data_D sum : 33529
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 6858263
# category_selection data_E sum : 71010
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9861751
# category_selection data_F sum : 100876
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_valerie!
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 29651185
# category_selection dy_M-100To200 sum : 5318578
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 6580175
# category_selection ttjets_dl sum : 14504
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 199496
# category_selection ttjets_sl sum : 96
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 115607
# category_selection st_tw_top sum : 1386
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 114306
# category_selection st_tw_antitop sum : 1307
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 337789
# category_selection ww_2l2nu sum : 32926
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 425164
# category_selection wz_3lnu sum : 4907
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2600161
# category_selection wz_2l2q sum : 1431
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 78009
# category_selection zz sum : 322
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1052640
# category_selection ewk_lljj_mll50_mjj120 sum : 339
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 30.613 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:30<00:00, 30.61s/it]
# Finished in 57.669 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46223 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:16,  1.09it/s]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:04<00:24,  1.47s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:04<00:19,  1.24s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:06<00:22,  1.52s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:10<00:28,  2.05s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:17<00:18,  1.88s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:18<00:12,  1.55s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:22<00:13,  1.98s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:23<00:09,  1.62s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:23<00:06,  1.33s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:23<00:04,  1.06s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:23<00:02,  1.18it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:24<00:01,  1.29it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:24<00:00,  1.24s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 3534725
# category_selection data_B sum : 14668
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 7092124
# category_selection data_C sum : 28671
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 3151971
# category_selection data_D sum : 12814
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 6858263
# category_selection data_E sum : 29262
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 9861751
# category_selection data_F sum : 43306
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins50!
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 29651185
# category_selection dy_M-100To200 sum : 3252777
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 6580175
# category_selection ttjets_dl sum : 149669
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 199496
# category_selection ttjets_sl sum : 848
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 115607
# category_selection st_tw_top sum : 8057
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 114306
# category_selection st_tw_antitop sum : 7878
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 337789
# category_selection ww_2l2nu sum : 19261
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 425164
# category_selection wz_3lnu sum : 7675
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2600161
# category_selection wz_2l2q sum : 10014
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 78009
# category_selection zz sum : 543
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1052640
# category_selection ewk_lljj_mll50_mjj120 sum : 3605
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 24.816 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:24<00:00, 24.82s/it]
# Finished in 49.66 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35239 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:17,  1.04it/s]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:04<00:26,  1.56s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:05<00:21,  1.31s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:07<00:24,  1.61s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:10<00:30,  2.17s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:18<00:19,  1.95s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:20<00:13,  1.65s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:24<00:14,  2.13s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:24<00:10,  1.74s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:24<00:06,  1.39s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:25<00:04,  1.11s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:25<00:02,  1.13it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:25<00:01,  1.22it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:26<00:00,  1.61it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:26<00:00,  1.31s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 3534725
# category_selection data_B sum : 14668
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 7092124
# category_selection data_C sum : 28671
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 3151971
# category_selection data_D sum : 12814
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 6858263
# category_selection data_E sum : 29262
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 9861751
# category_selection data_F sum : 43306
# var: dimuon_pt
# values is nan: False
# values is none: False
# ...
#  65%|███████████████████████████▉               | 13/20 [00:22<00:13,  1.94s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:22<00:09,  1.59s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:22<00:06,  1.27s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:23<00:04,  1.02s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:23<00:02,  1.24it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:23<00:01,  1.36it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:24<00:00,  1.75it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:24<00:00,  1.22s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 3534725
# category_selection data_B sum : 11307
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 7092124
# category_selection data_C sum : 22070
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 3151971
# category_selection data_D sum : 9877
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 6858263
# category_selection data_E sum : 22342
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 9861751
# category_selection data_F sum : 33349
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins100!
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 29651185
# category_selection dy_M-100To200 sum : 2127033
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 6580175
# category_selection ttjets_dl sum : 1113332
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 199496
# category_selection ttjets_sl sum : 14420
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 115607
# category_selection st_tw_top sum : 13151
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 114306
# category_selection st_tw_antitop sum : 13095
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 337789
# category_selection ww_2l2nu sum : 10917
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 425164
# category_selection wz_3lnu sum : 8324
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2600161
# category_selection wz_2l2q sum : 44054
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 78009
# category_selection zz sum : 842
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1052640
# category_selection ewk_lljj_mll50_mjj120 sum : 24959
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 28.146 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:28<00:00, 28.15s/it]
# Finished in 52.503 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44087 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:17,  1.05it/s]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:04<00:25,  1.50s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:05<00:20,  1.26s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:06<00:22,  1.48s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:10<00:28,  2.01s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:17<00:18,  1.89s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:19<00:12,  1.56s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:22<00:13,  1.99s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:23<00:09,  1.65s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:23<00:06,  1.32s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:23<00:04,  1.05s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:24<00:02,  1.14it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:24<00:01,  1.27it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2017/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:24<00:00,  1.25s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 3534725
# category_selection data_B sum : 11307
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 7092124
# category_selection data_C sum : 22070
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 3151971
# category_selection data_D sum : 9877
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 6858263
# category_selection data_E sum : 22342
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 9861751
# category_selection data_F sum : 33349
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_valerie!
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 29651185
# category_selection dy_M-100To200 sum : 2127033
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 6580175
# category_selection ttjets_dl sum : 1113332
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 199496
# category_selection ttjets_sl sum : 14420
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 115607
# category_selection st_tw_top sum : 13151
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 114306
# category_selection st_tw_antitop sum : 13095
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 337789
# category_selection ww_2l2nu sum : 10917
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 425164
# category_selection wz_3lnu sum : 8324
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2600161
# category_selection wz_2l2q sum : 44054
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 78009
# category_selection zz sum : 842
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1052640
# category_selection ewk_lljj_mll50_mjj120 sum : 24959
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 29.497 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:29<00:00, 29.50s/it]
# Finished in 54.485 s.

# %%
# """
# First we plot Zpt off stage1 plots to match AN-19-124 fig 4.3
# """
# # label = "V2_Jan09_ForZptReWgt"
# # label = "V2_Jan17_JecDefault_plotEveryonesZptWgt"
# label = "V2_Jan22_JecDefault_plotEveryonesZptWgt"

# # year = "2017"
# year = "2016postVFP"
# # year = "2016preVFP"
# lumi = lumi_dict[year]
# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
# plot_setting = "./plot_settings_Zpt_reWgt.json"

# keep_zpt_on = True # dummy value


# # njet = -1

# # # zpt_name = "zpt_weight_mine_nbins50"
# # # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_mine_nbins100"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # # zpt_name = "zpt_weight_dmitry"
# # # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_valerie"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 0

# zpt_name = "zpt_weight_mine_nbins50"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 1

# zpt_name = "zpt_weight_mine_nbins50"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 2

# zpt_name = "zpt_weight_mine_nbins50"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# %%
# """
# First we plot Zpt off stage1 plots to match AN-19-124 fig 4.3
# """
# # label = "V2_Jan09_ForZptReWgt"
# # label = "V2_Jan17_JecDefault_plotEveryonesZptWgt"
# label = "V2_Jan22_JecDefault_plotEveryonesZptWgt"

# # year = "2017"
# # year = "2016postVFP"
# year = "2016preVFP"
# lumi = lumi_dict[year]
# load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
# plot_setting = "./plot_settings_Zpt_reWgt.json"

# keep_zpt_on = True # dummy value


# # njet = -1

# # # zpt_name = "zpt_weight_mine_nbins50"
# # # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_mine_nbins100"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # # zpt_name = "zpt_weight_dmitry"
# # # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_valerie"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 0

# zpt_name = "zpt_weight_mine_nbins50"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 1

# zpt_name = "zpt_weight_mine_nbins50"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# njet = 2

# zpt_name = "zpt_weight_mine_nbins50"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_mine_nbins100"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# # zpt_name = "zpt_weight_dmitry"
# # ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# zpt_name = "zpt_weight_valerie"
# ! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
# Out:
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35953 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:03<00:31,  1.73s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:04<00:23,  1.40s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:05<00:20,  1.30s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:06<00:20,  1.35s/it]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:07<00:16,  1.16s/it]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:21<00:26,  2.64s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:23<00:16,  2.09s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:25<00:15,  2.18s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:26<00:10,  1.82s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:26<00:07,  1.46s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:26<00:04,  1.16s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:27<00:03,  1.02s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:28<00:01,  1.03it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:28<00:00,  1.29it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:29<00:00,  1.45s/it]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 4211943
# category_selection data_B sum : 44383
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1843778
# category_selection data_C sum : 19319
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3056490
# category_selection data_D sum : 32015
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2823161
# category_selection data_E sum : 30000
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1869945
# category_selection data_F sum : 19702
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins50!
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 5267991
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2332004
# category_selection ttjets_dl sum : 5433
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 69291
# category_selection ttjets_sl sum : 34
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 44998
# category_selection st_tw_top sum : 531
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 43296
# category_selection st_tw_antitop sum : 538
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 146575
# category_selection ww_2l2nu sum : 14398
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 405561
# category_selection wz_3lnu sum : 4682
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1395464
# category_selection wz_2l2q sum : 832
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 36980
# category_selection zz sum : 134
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 342514
# category_selection ewk_lljj_mll50_mjj120 sum : 106
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing dimuon_pt in 18.243 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:18<00:00, 18.24s/it]
# Finished in 47.274 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43095 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:17,  1.01it/s]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:02<00:15,  1.13it/s]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:03<00:15,  1.01it/s]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:04<00:14,  1.02it/s]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:05<00:12,  1.08it/s]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:12<00:14,  1.42s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:13<00:08,  1.10s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:14<00:08,  1.18s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:14<00:05,  1.04it/s]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:15<00:03,  1.30it/s]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:15<00:02,  1.64it/s]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:15<00:01,  1.91it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:15<00:01,  1.99it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:16<00:00,  1.24it/s]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 4211943
# category_selection data_B sum : 44383
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1843778
# category_selection data_C sum : 19319
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3056490
# category_selection data_D sum : 32015
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2823161
# category_selection data_E sum : 30000
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1869945
# category_selection data_F sum : 19702
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins100!
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 5267991
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2332004
# category_selection ttjets_dl sum : 5433
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 69291
# category_selection ttjets_sl sum : 34
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 44998
# category_selection st_tw_top sum : 531
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 43296
# category_selection st_tw_antitop sum : 538
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 146575
# category_selection ww_2l2nu sum : 14398
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 405561
# category_selection wz_3lnu sum : 4682
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1395464
# category_selection wz_2l2q sum : 832
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 36980
# category_selection zz sum : 134
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 342514
# category_selection ewk_lljj_mll50_mjj120 sum : 106
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing dimuon_pt in 21.101 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:21<00:00, 21.10s/it]
# Finished in 37.196 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44093 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:02<00:18,  1.02s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:02<00:15,  1.11it/s]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:03<00:16,  1.00s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:04<00:14,  1.01it/s]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:05<00:12,  1.10it/s]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:12<00:14,  1.47s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:13<00:09,  1.13s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:15<00:08,  1.20s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:15<00:05,  1.01it/s]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:15<00:03,  1.27it/s]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:15<00:02,  1.50it/s]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:16<00:01,  1.70it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:16<00:01,  1.94it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:16<00:00,  1.20it/s]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 4211943
# category_selection data_B sum : 44383
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1843778
# category_selection data_C sum : 19319
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 3056490
# category_selection data_D sum : 32015
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2823161
# category_selection data_E sum : 30000
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1869945
# category_selection data_F sum : 19702
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_valerie!
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 5267991
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2332004
# category_selection ttjets_dl sum : 5433
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 69291
# category_selection ttjets_sl sum : 34
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 44998
# category_selection st_tw_top sum : 531
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 43296
# category_selection st_tw_antitop sum : 538
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 146575
# category_selection ww_2l2nu sum : 14398
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 405561
# category_selection wz_3lnu sum : 4682
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1395464
# category_selection wz_2l2q sum : 832
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 36980
# category_selection zz sum : 134
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 342514
# category_selection ewk_lljj_mll50_mjj120 sum : 106
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing dimuon_pt in 20.758 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:20<00:00, 20.76s/it]
# Finished in 37.426 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45727 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:02<00:18,  1.00s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:02<00:14,  1.15it/s]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:03<00:15,  1.04it/s]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:04<00:14,  1.05it/s]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:05<00:12,  1.11it/s]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:12<00:14,  1.45s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:13<00:09,  1.13s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:14<00:08,  1.21s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:15<00:05,  1.01it/s]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
# loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:15<00:02,  1.52it/s]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:15<00:01,  1.73it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:15<00:01,  1.92it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:16<00:00,  2.40it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:16<00:00,  1.24it/s]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 4211943
# category_selection data_B sum : 16349
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1843778
# category_selection data_C sum : 7364
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 3056490
# category_selection data_D sum : 12084
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2823161
# category_selection data_E sum : 11547
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1869945
# category_selection data_F sum : 7661
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins50!
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 3059835
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 2332004
# category_selection ttjets_dl sum : 53958
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 69291
# category_selection ttjets_sl sum : 313
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 44998
# category_selection st_tw_top sum : 3153
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 43296
# category_selection st_tw_antitop sum : 3056
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 146575
# category_selection ww_2l2nu sum : 7904
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 405561
# category_selection wz_3lnu sum : 7377
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 1395464
# category_selection wz_2l2q sum : 5481
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 36980
# category_selection zz sum : 240
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 1
# category_selection length: 342514
# category_selection ewk_lljj_mll50_mjj120 sum : 1161
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 19.618 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:19<00:00, 19.62s/it]
# Finished in 35.754 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42163 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:17,  1.02it/s]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:02<00:14,  1.18it/s]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:03<00:15,  1.06it/s]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:04<00:14,  1.06it/s]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:05<00:12,  1.12it/s]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:12<00:13,  1.38s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:12<00:08,  1.08s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:14<00:08,  1.16s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:14<00:05,  1.05it/s]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:14<00:03,  1.32it/s]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:14<00:02,  1.66it/s]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:15<00:01,  1.93it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:15<00:00,  2.16it/s]loading process zz..
# ...
#  65%|███████████████████████████▉               | 13/20 [00:14<00:08,  1.17s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:14<00:05,  1.05it/s]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
# loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:14<00:02,  1.57it/s]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:15<00:01,  1.78it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:15<00:01,  1.97it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:15<00:00,  1.29it/s]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 4211943
# category_selection data_B sum : 12928
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1843778
# category_selection data_C sum : 5732
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 3056490
# category_selection data_D sum : 9156
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2823161
# category_selection data_E sum : 8665
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1869945
# category_selection data_F sum : 5697
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_mine_nbins100!
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 1935749
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2332004
# category_selection ttjets_dl sum : 386581
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 69291
# category_selection ttjets_sl sum : 4924
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 44998
# category_selection st_tw_top sum : 4987
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 43296
# category_selection st_tw_antitop sum : 4789
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 146575
# category_selection ww_2l2nu sum : 4357
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 405561
# category_selection wz_3lnu sum : 7352
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1395464
# category_selection wz_2l2q sum : 23317
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 36980
# category_selection zz sum : 436
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 342514
# category_selection ewk_lljj_mll50_mjj120 sum : 8232
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 18.025 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:18<00:00, 18.03s/it]
# Finished in 33.587 s.
# variables2plot: ['dimuon_pt']
# /depot/cms/kernels/coffea_latest/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 32971 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_A/*.parquet Not available. Skipping
# loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:01<00:16,  1.07it/s]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:02<00:14,  1.20it/s]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:03<00:14,  1.08it/s]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_E/*/*.parquet
#  25%|███████████                                 | 5/20 [00:04<00:13,  1.09it/s]loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_F/*/*.parquet
#  30%|█████████████▏                              | 6/20 [00:05<00:12,  1.16it/s]loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-50/*.parquet Not available. Skipping
# loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:11<00:13,  1.37s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:12<00:08,  1.07s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:14<00:08,  1.15s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:14<00:05,  1.07it/s]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:14<00:03,  1.34it/s]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:14<00:02,  1.70it/s]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:14<00:01,  1.86it/s]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:15<00:00,  2.11it/s]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//zz/*/*.parquet
# loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/V2_Jan22_JecDefault_plotEveryonesZptWgt/stage1_output/2016preVFP/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:15<00:00,  1.29it/s]
# finished loading parquet files!
#   0%|                                                     | 0/1 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# skipping data_A
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 4211943
# category_selection data_B sum : 12928
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1843778
# category_selection data_C sum : 5732
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 3056490
# category_selection data_D sum : 9156
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2823161
# category_selection data_E sum : 8665
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_F
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1869945
# category_selection data_F sum : 5697
# var: dimuon_pt
# values is nan: False
# values is none: False
# data activated
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# skipping dy_M-50
# process: dy_M-100To200
# is_data: False
# applying Zpt rewgt zpt_weight_valerie!
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 28532506
# category_selection dy_M-100To200 sum : 1935749
# var: dimuon_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2332004
# category_selection ttjets_dl sum : 386581
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 69291
# category_selection ttjets_sl sum : 4924
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 44998
# category_selection st_tw_top sum : 4987
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 43296
# category_selection st_tw_antitop sum : 4789
# var: dimuon_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 146575
# category_selection ww_2l2nu sum : 4357
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 405561
# category_selection wz_3lnu sum : 7352
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1395464
# category_selection wz_2l2q sum : 23317
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 36980
# category_selection zz sum : 436
# var: dimuon_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 342514
# category_selection ewk_lljj_mll50_mjj120 sum : 8232
# var: dimuon_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing dimuon_pt in 16.714 s.
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.71s/it]
# Finished in 32.185 s.
