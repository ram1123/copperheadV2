# %% [markdown]
# # Zpt re-wgt Validation
#
# This notebook shows the script to plot ZpT-rewgt validation code to verify that the Zpt-rewgt has been properly generated
#
# This script is inspired from validation_plotter_unified.py, and thus share a lot of same formatting.

# %%
data_l = ['A', 'B', 'C', 'D','E', 'F','H', 'G']
bkg_l = ['DY','TT','ST','VV','EWK']
# bkg_l = ['DY','TT','ST','VV']
# sig_l = ['ggH', 'VBF']
sig_l = []

# vars2plot = ['dimuon']
vars2plot = ['mu']

lumi_dict = {
    "2018" : 59.83,
    "2017" : 41.48,
    "2016postVFP": 19.5,
    "2016preVFP": 16.81,
}
status = "Private_Work"
# region = "signal"
region = "z-peak"

# %%
"""
First we plot Zpt off stage1 plots to match AN-19-124 fig 4.3
"""
# label = "V2_Jan09_ForZptReWgt"
# label = "V2_Jan17_JecDefault_plotEveryonesZptWgt"
# label = "V2_Jan22_JecDefault_plotEveryonesZptWgt"
# label="UpdatedDY_100_200_CrossSection_24Feb"
label="UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff/"

year = "2018"
# year = "2017"
# year = "2016postVFP"
# year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

category="nocat"
# category="ggh"

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
# Out:
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41327 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:37,  5.14s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:07<01:04,  3.56s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:09<00:50,  2.99s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:21<01:39,  6.21s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-50/*/*.parquet
#  45%|███████████████████▊                        | 9/20 [00:27<00:27,  2.53s/it]loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:35<00:36,  3.63s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:39<00:23,  2.96s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:46<00:25,  3.71s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:46<00:17,  2.98s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:46<00:11,  2.34s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:47<00:07,  1.85s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:47<00:04,  1.44s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:48<00:02,  1.29s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:48<00:00,  1.03it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:48<00:00,  2.44s/it]
# finished loading parquet files!
#   0%|                                                     | 0/4 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 9635946
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 4879080
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 4776470
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 22118532
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 21688643
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 16758295
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 2626687
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 120618
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 43763
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 42576
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 153481
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 334222
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 2390432
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 97356
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1302323
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu1_pt in 60.288 s.
#  25%|███████████▎                                 | 1/4 [01:00<03:00, 60.29s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 9635946
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 4879080
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 4776470
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 22118532
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 21688643
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 16758295
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 2626687
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 120618
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 43763
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 42576
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 153481
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 334222
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 2390432
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 97356
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1302323
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing mu2_pt in 54.112 s.
#  50%|██████████████████████▌                      | 2/4 [01:54<01:53, 56.66s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:54<00:00, 28.60s/it]
# Finished in 163.219 s.
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46113 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:36,  5.06s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:07<01:00,  3.37s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:09<00:47,  2.77s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:19<01:33,  5.85s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-50/*/*.parquet
#  45%|███████████████████▊                        | 9/20 [00:26<00:26,  2.45s/it]loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:34<00:34,  3.43s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:37<00:22,  2.83s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:43<00:24,  3.52s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:44<00:17,  2.85s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:44<00:11,  2.23s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:44<00:07,  1.76s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:45<00:04,  1.36s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:45<00:02,  1.23s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:46<00:00,  1.06it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:46<00:00,  2.32s/it]
# finished loading parquet files!
#   0%|                                                     | 0/4 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 9635946
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 4879080
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 4776470
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 22118532
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 21688643
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 16758295
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 2626687
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 120618
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 43763
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 42576
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 153481
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 334222
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 2390432
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 97356
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1302323
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu1_pt in 55.41 s.
#  25%|███████████▎                                 | 1/4 [00:55<02:46, 55.41s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 9635946
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 4879080
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 4776470
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 22118532
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 21688643
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 16758295
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 2626687
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 120618
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 43763
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 42576
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 153481
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 334222
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 2390432
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 97356
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1302323
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing mu2_pt in 50.336 s.
#  50%|██████████████████████▌                      | 2/4 [01:45<01:44, 52.43s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:45<00:00, 26.44s/it]
# Finished in 152.238 s.
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45619 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:35,  5.03s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:07<01:00,  3.37s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:09<00:47,  2.78s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:20<01:36,  6.01s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-50/*/*.parquet
#  45%|███████████████████▊                        | 9/20 [00:26<00:27,  2.49s/it]loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:34<00:34,  3.44s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:37<00:22,  2.84s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:43<00:24,  3.50s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:44<00:17,  2.84s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:44<00:11,  2.23s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:45<00:07,  1.78s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:45<00:04,  1.38s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:46<00:02,  1.23s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:46<00:00,  1.07it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:46<00:00,  2.34s/it]
# finished loading parquet files!
#   0%|                                                     | 0/4 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 10537085
# category_selection data_A sum : 6405961
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5343474
# category_selection data_B sum : 3298468
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5231923
# category_selection data_C sum : 3159685
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 24236950
# category_selection data_D sum : 14940377
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 22428517
# category_selection dy_M-50 sum : 12302641
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 8957325
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9255046
# category_selection ttjets_dl sum : 30059
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 289491
# category_selection ttjets_sl sum : 541
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 158318
# category_selection st_tw_top sum : 2771
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 152860
# category_selection st_tw_antitop sum : 2622
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 499610
# category_selection ww_2l2nu sum : 83733
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 420719
# category_selection wz_3lnu sum : 76027
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2625002
# category_selection wz_2l2q sum : 80111
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 105027
# category_selection zz sum : 18418
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 5783
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu1_pt in 53.046 s.
#  25%|███████████▎                                 | 1/4 [00:53<02:39, 53.05s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 10537085
# category_selection data_A sum : 6405961
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5343474
# category_selection data_B sum : 3298468
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 5231923
# category_selection data_C sum : 3159685
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 24236950
# category_selection data_D sum : 14940377
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 22428517
# category_selection dy_M-50 sum : 12302641
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 8957325
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 9255046
# category_selection ttjets_dl sum : 30059
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 289491
# category_selection ttjets_sl sum : 541
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 158318
# category_selection st_tw_top sum : 2771
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 152860
# category_selection st_tw_antitop sum : 2622
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 499610
# category_selection ww_2l2nu sum : 83733
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 420719
# category_selection wz_3lnu sum : 76027
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 2625002
# category_selection wz_2l2q sum : 80111
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 105027
# category_selection zz sum : 18418
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 0
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 5783
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu2_pt in 43.102 s.
#  50%|██████████████████████▌                      | 2/4 [01:36<01:34, 47.20s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:36<00:00, 24.04s/it]
# Finished in 142.868 s.
# 2025-03-25 20:39:58,168 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
# ...
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 105027
# category_selection zz sum : 50184
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1181501
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing mu2_pt in 34.724 s.
#  50%|██████████████████████▌                      | 2/4 [01:16<01:15, 37.52s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:16<00:00, 19.06s/it]
# Finished in 122.204 s.
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 32933 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:36,  5.05s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:07<01:00,  3.38s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:09<00:47,  2.79s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:20<01:35,  5.95s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-50/*/*.parquet
#  45%|███████████████████▊                        | 9/20 [00:26<00:27,  2.48s/it]loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:34<00:34,  3.45s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:37<00:22,  2.85s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:44<00:24,  3.52s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:44<00:17,  2.84s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:44<00:11,  2.23s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:45<00:07,  1.75s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:45<00:04,  1.36s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:46<00:02,  1.20s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:46<00:00,  1.09it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:46<00:00,  2.33s/it]
# finished loading parquet files!
#   0%|                                                     | 0/4 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 10537085
# category_selection data_A sum : 1011995
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 5343474
# category_selection data_B sum : 487091
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 5231923
# category_selection data_C sum : 508942
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 24236950
# category_selection data_D sum : 2227023
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 22428517
# category_selection dy_M-50 sum : 3496796
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 2971461
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 9255046
# category_selection ttjets_dl sum : 2281861
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 289491
# category_selection ttjets_sl sum : 113625
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 158318
# category_selection st_tw_top sum : 25102
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 152860
# category_selection st_tw_antitop sum : 24529
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 499610
# category_selection ww_2l2nu sum : 23912
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 420719
# category_selection wz_3lnu sum : 135770
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2625002
# category_selection wz_2l2q sum : 1845199
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 105027
# category_selection zz sum : 50184
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1181501
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu1_pt in 41.557 s.
#  25%|███████████▎                                 | 1/4 [00:41<02:04, 41.56s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 10537085
# category_selection data_A sum : 1011995
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 5343474
# category_selection data_B sum : 487091
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 5231923
# category_selection data_C sum : 508942
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 24236950
# category_selection data_D sum : 2227023
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 22428517
# category_selection dy_M-50 sum : 3496796
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# removing Zpt rewgt!
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 2971461
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 9255046
# category_selection ttjets_dl sum : 2281861
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 289491
# category_selection ttjets_sl sum : 113625
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 158318
# category_selection st_tw_top sum : 25102
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 152860
# category_selection st_tw_antitop sum : 24529
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 499610
# category_selection ww_2l2nu sum : 23912
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 420719
# category_selection wz_3lnu sum : 135770
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 2625002
# category_selection wz_2l2q sum : 1845199
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 105027
# category_selection zz sum : 50184
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: z-peak
# nocat mode!
# jet_multiplicity: 2
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 1181501
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# Finished processing mu2_pt in 33.484 s.
#  50%|██████████████████████▌                      | 2/4 [01:15<01:13, 36.81s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:15<00:00, 18.76s/it]
# Finished in 121.655 s.

# %%
region = "signal"
year="2018"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
# Out:
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40513 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:48,  5.72s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:08<01:11,  3.95s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:11<00:57,  3.36s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:22<01:46,  6.67s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-50/*/*.parquet
#  45%|███████████████████▊                        | 9/20 [00:30<00:30,  2.81s/it]loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:38<00:38,  3.84s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:42<00:25,  3.20s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:49<00:27,  3.88s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:49<00:18,  3.13s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:50<00:12,  2.47s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:50<00:07,  1.94s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:50<00:04,  1.53s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:51<00:02,  1.34s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:51<00:01,  1.03s/it]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:52<00:00,  2.62s/it]
# finished loading parquet files!
#   0%|                                                     | 0/4 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 182601
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 92303
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 90292
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 417682
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 3222
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 10857690
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 1766569
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 21093
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 30730
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 29238
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 90833
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 20026
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 55336
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 2310
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 38826
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu1_pt in 45.58 s.
#  25%|███████████▎                                 | 1/4 [00:45<02:16, 45.58s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 182601
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 92303
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 90292
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 417682
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 3222
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 10857690
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 1766569
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 21093
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 30730
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 29238
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 90833
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 20026
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 55336
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 2310
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 38826
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing mu2_pt in 34.367 s.
#  50%|██████████████████████▌                      | 2/4 [01:19<01:17, 38.98s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:19<00:00, 19.99s/it]
# Finished in 132.263 s.
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37983 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:37,  5.12s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:07<01:01,  3.42s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:09<00:47,  2.81s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet
#  20%|████████▊                                   | 4/20 [00:20<01:34,  5.89s/it]loading process data_E..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_E/*.parquet Not available. Skipping
# loading process data_F..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_F/*.parquet Not available. Skipping
# loading process data_H..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_H/*.parquet Not available. Skipping
# loading process data_G..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_G/*.parquet Not available. Skipping
# loading process dy_M-50..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-50/*/*.parquet
#  45%|███████████████████▊                        | 9/20 [00:25<00:26,  2.42s/it]loading process dy_M-100To200..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_M-100To200/*/*.parquet
#  50%|█████████████████████▌                     | 10/20 [00:33<00:33,  3.36s/it]loading process dy_m105_160_amc..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//dy_m105_160_amc/*.parquet Not available. Skipping
# loading process ttjets_dl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_dl/*/*.parquet
#  60%|█████████████████████████▊                 | 12/20 [00:37<00:22,  2.78s/it]loading process ttjets_sl..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ttjets_sl/*/*.parquet
#  65%|███████████████████████████▉               | 13/20 [00:43<00:24,  3.47s/it]loading process st_tw_top..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_top/*/*.parquet
#  70%|██████████████████████████████             | 14/20 [00:43<00:16,  2.79s/it]loading process st_tw_antitop..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//st_tw_antitop/*/*.parquet
#  75%|████████████████████████████████▎          | 15/20 [00:44<00:11,  2.21s/it]loading process ww_2l2nu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ww_2l2nu/*/*.parquet
#  80%|██████████████████████████████████▍        | 16/20 [00:44<00:07,  1.76s/it]loading process wz_3lnu..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_3lnu/*/*.parquet
#  85%|████████████████████████████████████▌      | 17/20 [00:44<00:04,  1.38s/it]loading process wz_2l2q..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//wz_2l2q/*/*.parquet
#  90%|██████████████████████████████████████▋    | 18/20 [00:45<00:02,  1.21s/it]loading process zz..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//zz/*/*.parquet
#  95%|████████████████████████████████████████▊  | 19/20 [00:45<00:00,  1.10it/s]loading process ewk_lljj_mll50_mjj120..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//ewk_lljj_mll50_mjj120/*/*.parquet
# 100%|███████████████████████████████████████████| 20/20 [00:46<00:00,  2.30s/it]
# finished loading parquet files!
#   0%|                                                     | 0/4 [00:00<?, ?it/s]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 182601
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 92303
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 90292
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 417682
# var: mu1_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# removing Zpt rewgt!
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 3222
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# removing Zpt rewgt!
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 10857690
# var: mu1_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 1766569
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 21093
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 30730
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 29238
# var: mu1_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 90833
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 20026
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 55336
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 2310
# var: mu1_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 38826
# var: mu1_pt
# values is nan: False
# values is none: False
# Ewk activated
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# /work/users/yun79/valerie/fork/copperheadV2/src/lib/histogram/plotting.py:156: RuntimeWarning: invalid value encountered in divide
#   rel_unc_ratio = np.sqrt((bkg_mc_err/bkg_mc_sum)**2 + (data_hist_err/data_hist)**2)
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/hist/intervals.py:68: RuntimeWarning: divide by zero encountered in divide
#   counts: np.typing.NDArray[Any] = values / scale
# Finished processing mu1_pt in 44.514 s.
#  25%|███████████▎                                 | 1/4 [00:44<02:13, 44.51s/it]do_logscale: True
# process: data_A
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 10537085
# category_selection data_A sum : 182601
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_B
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5343474
# category_selection data_B sum : 92303
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_C
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 5231923
# category_selection data_C sum : 90292
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_D
# is_data: True
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 24236950
# category_selection data_D sum : 417682
# var: mu2_pt
# values is nan: False
# values is none: False
# data activated
# process: data_E
# skipping data_E
# process: data_F
# skipping data_F
# process: data_H
# skipping data_H
# process: data_G
# skipping data_G
# process: dy_M-50
# is_data: False
# removing Zpt rewgt!
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 22428517
# category_selection dy_M-50 sum : 3222
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_M-100To200
# is_data: False
# removing Zpt rewgt!
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 30258706
# category_selection dy_M-100To200 sum : 10857690
# var: mu2_pt
# values is nan: False
# values is none: False
# DY activated
# process: dy_m105_160_amc
# skipping dy_m105_160_amc
# process: ttjets_dl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 9255046
# category_selection ttjets_dl sum : 1766569
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ttjets_sl
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 289491
# category_selection ttjets_sl sum : 21093
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_top
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 158318
# category_selection st_tw_top sum : 30730
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: st_tw_antitop
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 152860
# category_selection st_tw_antitop sum : 29238
# var: mu2_pt
# values is nan: False
# values is none: False
# top activated
# process: ww_2l2nu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 499610
# category_selection ww_2l2nu sum : 90833
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_3lnu
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 420719
# category_selection wz_3lnu sum : 20026
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: wz_2l2q
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 2625002
# category_selection wz_2l2q sum : 55336
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: zz
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 105027
# category_selection zz sum : 2310
# var: mu2_pt
# values is nan: False
# values is none: False
# VV activated
# process: ewk_lljj_mll50_mjj120
# is_data: False
# args.region: signal
# nocat mode!
# jet_multiplicity: -1
# category_selection length: 1417484
# category_selection ewk_lljj_mll50_mjj120 sum : 38826
# var: mu2_pt
# values is nan: False
# values is none: False
# Ewk activated
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:251: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# Finished processing mu2_pt in 37.243 s.
#  50%|██████████████████████▌                      | 2/4 [01:21<01:20, 40.24s/it]variable mu1_pt_over_mass not configured in plot settings!
# variable mu2_pt_over_mass not configured in plot settings!
# 100%|█████████████████████████████████████████████| 4/4 [01:21<00:00, 20.44s/it]
# Finished in 127.799 s.
# variables2plot: ['mu1_pt', 'mu2_pt', 'mu1_pt_over_mass', 'mu2_pt_over_mass']
# /depot/cms/kernels/coffea_latest/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33379 instead
#   warnings.warn(
# Local scale Client created
# available_processes: ['data_A', 'data_B', 'data_C', 'data_D', 'data_E', 'data_F', 'data_H', 'data_G', 'dy_M-50', 'dy_M-100To200', 'dy_m105_160_amc', 'ttjets_dl', 'ttjets_sl', 'st_tw_top', 'st_tw_antitop', 'ww_2l2nu', 'wz_3lnu', 'wz_2l2q', 'zz', 'ewk_lljj_mll50_mjj120']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]loading process data_A..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_A/*/*.parquet
#   5%|██▏                                         | 1/20 [00:05<01:36,  5.06s/it]loading process data_B..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_B/*/*.parquet
#  10%|████▍                                       | 2/20 [00:07<01:01,  3.40s/it]loading process data_C..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_C/*/*.parquet
#  15%|██████▌                                     | 3/20 [00:09<00:47,  2.80s/it]loading process data_D..
# full_load_path: /depot/cms/users/yun79/hmm/copperheadV1clean/UpdatedDY_100_200_CrossSection_24Feb_jetpuidOff//stage1_output/2018/f1_0//data_D/*/*.parquet

# %%
year = "2016postVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

# %%
year = "2016preVFP"
lumi = lumi_dict[year]
load_path = f"/depot/cms/users/yun79/hmm/copperheadV1clean/{label}/stage1_output/{year}/f1_0/"
plot_setting = "./plot_settings_Zpt_reWgt.json"

keep_zpt_on = True # dummy value

njet = -1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat {category} -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 0

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

njet = 1

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}


njet = 2

zpt_name = "yes_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}

zpt_name = "no_zpt"
! python zpt_validation_plotter.py -y {year} --load_path {load_path}  -var {' '.join(vars2plot)} --data {' '.join(data_l)} --background {' '.join(bkg_l)} --signal {' '.join(sig_l)} --lumi {lumi} --status {status} -cat nocat -reg {region} --label {label} --plot_setting {plot_setting} --zpt_on {keep_zpt_on} --jet_multiplicity {njet} --zpt_wgt_name {zpt_name}
