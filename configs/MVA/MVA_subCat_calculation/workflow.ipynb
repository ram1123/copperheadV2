# %% [markdown]
# First, we obtain the MVA score edges for given signal efficiency

# %%
import time
import numpy as np
import pickle
import awkward as ak
import dask_awkward as dak
from distributed import Client
import pandas as pd

from typing import Tuple, List, Dict
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
import mplhep as hep
import matplotlib.pyplot as plt
import matplotlib
plt.style.use(hep.style.CMS)
import numba 

@numba.njit(parallel=True)
def customROC_curve_AN(label, pred, weight):
    """
    generates signal and background efficiency consistent with the AN,
    as described by Fig 4.6 of Dmitry's PhD thesis
    """
    # we assume sigmoid output with labels 0 = background, 1 = signal
    thresholds = np.linspace(start=0,stop=1, num=10000) 
    # thresholds = np.linspace(start=0,stop=1, num=500)
    effBkg_total = -99*np.ones_like(thresholds) 
    effSig_total = -99*np.ones_like(thresholds) 
    # for ix in range(len(thresholds)):
    for ix in numba.prange(len(thresholds)):
        threshold = thresholds[ix]
        # get FP and TP
        positive_filter = (pred >= threshold)
        falsePositive_filter = positive_filter & (label == 0)
        FP = np.sum(weight[falsePositive_filter])#  FP = false positive
        truePositive_filter = positive_filter & (label == 1)
        TP = np.sum(weight[truePositive_filter])#  TP = true positive
        

        # get TN and FN
        negative_filter = (pred < threshold) # just picked negative to be <=
        trueNegative_filter = negative_filter & (label == 0)
        TN = np.sum(weight[trueNegative_filter])#  TN = true negative
        falseNegative_filter = negative_filter & (label == 1)
        FN = np.sum(weight[falseNegative_filter])#  FN = false negative
     


        # effBkg = TN / (TN + FP) # Dmitry PhD thesis definition
        # effSig = FN / (FN + TP) # Dmitry PhD thesis definition
        effBkg = FP / (TN + FP) # AN-19-124 ggH Cat definition
        effSig = TP / (FN + TP) # AN-19-124 ggH Cat definition
        effBkg_total[ix] = effBkg
        effSig_total[ix] = effSig
        

        # print(f"effSig: {effSig}")
        # print(f"FN: {FN}")
        # print(f"TP: {TP}")
        # print(f"threshold: {threshold}")
        
        # sanity check
        # assert ((np.sum(positive_filter) + np.sum(negative_filter)) == len(pred))
        # total_yield = FP + TP + FN + TN
        # assert(np.isclose(total_yield, np.sum(weight)))
        # print(f"total_yield: {total_yield}")
        # print(f"np.sum(weight): {np.sum(weight)}")
    print(f"np.sum(effBkg_total ==-99) : {np.sum(effBkg_total ==-99)}")
    print(f"np.sum(effSig_total ==-99) : {np.sum(effSig_total ==-99)}")
    print(f"np.any(np.isnan(effBkg_total)) : {np.any(np.isnan(effBkg_total))}")
    print(f"np.any(np.isnan(effSig_total)) : {np.any(np.isnan(effSig_total))}")
    # effBkg_total[np.isnan(effBkg_total)] = 1
    # effSig_total[np.isnan(effSig_total)] = 1
    return (effBkg_total, effSig_total, thresholds)

def findBDT_binVals_basedOnSigEff(thres, eff_sigs, sigEffBinEdges):
    """
    we expect len(sigEffBinEdges) == number of categories + 1,
    we expect sshape of thres == shape of eff_sigs
    """
    bin_vals = []
    for target_eff in sigEffBinEdges:
        # print(f"target_eff: {target_eff}")
        for ix in range(1,len(eff_sigs)):
            # print(f"ix: {ix}")
            ith_sigEff = eff_sigs[ix]
            sigEff_oneb4 = eff_sigs[ix-1]
            thres_oneb4 = thres[ix-1]
            thres_current = thres[ix]
            
            if target_eff >= ith_sigEff:
                # print(f"target_eff: {target_eff}")
                # print(f"ith_sigEff: {ith_sigEff}")
                # print(f"sigEff_oneb4: {sigEff_oneb4}")
                # print(f"thres_current: {thres_current}")
                # print(f"thres_oneb4: {thres_oneb4}")
                bin_vals.append(thres_current)
                break
        # print(f"-----------------------------------------")
    return bin_vals


def getMVA_values(initial_load_path: str):
    # year = "2016preVFP"
    # stage2_out_name = "BDT_WgtON_original_AN_BDT_Sept27"
    
    # load_path = f"/work/users/yun79/stage2_output/{stage2_out_name}/ggh/{year}/processed_events_bkgMC*.parquet"
    load_path = f"{initial_load_path}/processed_events_bkgMC*.parquet"
    
    processed_events = ak.from_parquet(load_path)
    nan_filter = ~np.isnan(ak.to_numpy(processed_events.wgt_nominal_total))
    processed_events = processed_events[nan_filter]
    region = processed_events.h_peak | processed_events.h_sidebands
    # DNN_score_raw is a sigmoid output
    bkg = (ak.to_numpy(processed_events.BDT_score[region])) # eval
    bkg_wgt = (ak.to_numpy(processed_events.wgt_nominal_total[region]))
    bkg_label = 0*np.ones_like(bkg)
    
    # we only have ggH and VBF for signal, which I hope is enough
    load_path = f"{initial_load_path}/processed_events_sigMC*.parquet"
    
    
    processed_events = ak.from_parquet(load_path)
    region = processed_events.h_peak | processed_events.h_sidebands
    sig = (ak.to_numpy(processed_events.BDT_score[region])) # eval
    sig_wgt = (ak.to_numpy(processed_events.wgt_nominal_total[region]))
    sig_label = np.ones_like(sig)
    
    pred = np.concatenate((bkg,sig), axis=0)
    wgt_total = np.concatenate((bkg_wgt,sig_wgt), axis=0)
    label = np.concatenate((bkg_label,sig_label), axis=0)

    eff_bkg, eff_sig, thresholds = customROC_curve_AN(label, pred, wgt_total)
    # print(f"eff_sig: {eff_sig}")
    # print to debug start ------------------------------------
    # plt.figure()  
    # plt.plot(eff_sig, eff_bkg, label="Stage2 ROC Curve (Eval)")
    
    # # plt.vlines(eff_sig, 0, eff_bkg, linestyle="dashed")
    # plt.vlines(np.linspace(0,1,11), 0, 1, linestyle="dashed", color="grey")
    # plt.hlines(np.logspace(-4,0,5), 0, 1, linestyle="dashed", color="grey")
    # # plt.hlines(eff_bkg, 0, eff_sig, linestyle="dashed")
    # plt.xlim([0.0, 1.0])
    # # plt.ylim([0.0, 1.0])
    # plt.xlabel('Signal eff')
    # plt.yscale("log")
    # plt.ylim([0.0001, 1.0])
    # plt.ylabel('Background eff')
    # plt.title(f'ROC curve for ggH BDT {year}')
    # # plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    # plt.legend()
    # plt.show()
    
    # plt.clf()
    # print to debug end ------------------------------------

    sigEffBinEdges = np.arange(0.99, 0.0, step=-0.01) # from 0.99 to 0.01 
    bin_vals = findBDT_binVals_basedOnSigEff(thresholds, eff_sig, sigEffBinEdges)
    print(bin_vals) 
    df = pd.DataFrame(columns=["year", "sig_eff","BDT_threshold"])
    df["sig_eff"] = sigEffBinEdges
    df["BDT_threshold"] = bin_vals
    df["year"] = year
    df.to_csv(f"BDT_threshold_{year}.csv")

# %%
years = [
    "2016preVFP",
    "2016postVFP",
    "2017",
    "2018",
]
stage2_out_name = "BDT_WgtON_original_AN_BDT_Sept27"
for year in years:
    load_path = f"/work/users/yun79/stage2_output/{stage2_out_name}/ggh/{year}"
    getMVA_values(load_path)
# Out:
# np.sum(effBkg_total ==-99) : 0
# np.sum(effSig_total ==-99) : 0
# np.any(np.isnan(effBkg_total)) : False
# np.any(np.isnan(effSig_total)) : False
# [0.0335033503350335, 0.04070407040704071, 0.04590459045904591, 0.0503050305030503, 0.054405440544054405, 0.058005800580058005, 0.06140614061406141, 0.06460646064606461, 0.06780678067806781, 0.0707070707070707, 0.07350735073507352, 0.07630763076307631, 0.07910791079107911, 0.0817081708170817, 0.08410841084108411, 0.08650865086508651, 0.08890889088908892, 0.09130913091309131, 0.09350935093509351, 0.09580958095809582, 0.09800980098009801, 0.10021002100210022, 0.10241024102410241, 0.10461046104610461, 0.10671067106710672, 0.10881088108810881, 0.11101110111011102, 0.11311131113111311, 0.11521152115211522, 0.11731173117311731, 0.11941194119411942, 0.12141214121412142, 0.12351235123512351, 0.1255125512551255, 0.1275127512751275, 0.12951295129512952, 0.13151315131513153, 0.1335133513351335, 0.13561356135613561, 0.13761376137613762, 0.13971397139713973, 0.1417141714171417, 0.14371437143714372, 0.14581458145814583, 0.14791479147914793, 0.15001500150015, 0.15211521152115212, 0.15421542154215423, 0.1562156215621562, 0.15841584158415842, 0.16061606160616063, 0.16281628162816283, 0.16501650165016502, 0.16731673167316732, 0.16951695169516953, 0.1717171717171717, 0.17401740174017402, 0.17631763176317633, 0.1786178617861786, 0.18101810181018102, 0.18351835183518353, 0.186018601860186, 0.18851885188518852, 0.19111911191119113, 0.1937193719371937, 0.19641964196419642, 0.19921992199219923, 0.20202020202020202, 0.20482048204820483, 0.20792079207920794, 0.21092109210921092, 0.21412141214121413, 0.21742174217421742, 0.22082208220822083, 0.22452245224522452, 0.22812281228122813, 0.23202320232023202, 0.23592359235923593, 0.23992399239923992, 0.24412441244124414, 0.24872487248724873, 0.2534253425342534, 0.2583258325832583, 0.2635263526352635, 0.26892689268926895, 0.27442744274427444, 0.28032803280328034, 0.28642864286428643, 0.29322932293229326, 0.30073007300730076, 0.30863086308630866, 0.31813181318131817, 0.32963296329632963, 0.34493449344934496, 0.36613661366136613, 0.39223922392239224, 0.42544254425442546, 0.47134713471347134, 0.5417541754175418]
# np.sum(effBkg_total ==-99) : 0
# np.sum(effSig_total ==-99) : 0
# np.any(np.isnan(effBkg_total)) : False
# np.any(np.isnan(effSig_total)) : False
    "2018",
]

sigEffBinEdges = np.arange(0.99, 0.0, step=-0.01) # from 0.99 to 0.01 
for sig_eff in sigEffBinEdges:
    for year in years:
        print(f"year: {year}")
        
        df = pd.read_csv(f"BDT_threshold_{year}.csv")
        bool_filter = np.isclose(df["sig_eff"], sig_eff)
        if np.sum(np.isclose(df["sig_eff"], sig_eff)) < 1:
            print("ERROR!")
        threshold = df["BDT_threshold"][bool_filter].values
        print(f"threshold: {threshold}")
        print("----------------------------------------------")
# Out:
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.03350335]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.03390339]
# year: 2017
# ----------------------------------------------
# threshold: [0.03310331]
# year: 2018
# ----------------------------------------------
# threshold: [0.03320332]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.04070407]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.04070407]
# year: 2017
# ----------------------------------------------
# threshold: [0.04020402]
# year: 2018
# ----------------------------------------------
# threshold: [0.04030403]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.04590459]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.0460046]
# year: 2017
# ----------------------------------------------
# threshold: [0.04540454]
# year: 2018
# ----------------------------------------------
# threshold: [0.04550455]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.05030503]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.05040504]
# year: 2017
# ----------------------------------------------
# threshold: [0.04990499]
# year: 2018
# ----------------------------------------------
# threshold: [0.050005]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.05440544]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.05420542]
# year: 2017
# ----------------------------------------------
# threshold: [0.05380538]
# year: 2018
# ----------------------------------------------
# threshold: [0.05390539]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.0580058]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.05790579]
# year: 2017
# ----------------------------------------------
# threshold: [0.05750575]
# year: 2018
# ----------------------------------------------
# threshold: [0.05750575]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.06140614]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.06130613]
# year: 2017
# ----------------------------------------------
# threshold: [0.0610061]
# year: 2018
# ----------------------------------------------
# threshold: [0.06090609]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.06460646]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.06450645]
# year: 2017
# ----------------------------------------------
# threshold: [0.06430643]
# year: 2018
# ----------------------------------------------
# threshold: [0.06420642]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.06780678]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.06740674]
# year: 2017
# ----------------------------------------------
# threshold: [0.06730673]
# year: 2018
# ----------------------------------------------
# threshold: [0.06720672]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.07070707]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.07030703]
# year: 2017
# ----------------------------------------------
# threshold: [0.07020702]
# year: 2018
# ----------------------------------------------
# threshold: [0.07010701]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.07350735]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.07310731]
# year: 2017
# ----------------------------------------------
# threshold: [0.07310731]
# year: 2018
# ----------------------------------------------
# threshold: [0.0730073]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.07630763]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.07590759]
# year: 2017
# ----------------------------------------------
# threshold: [0.07580758]
# year: 2018
# ----------------------------------------------
# threshold: [0.07570757]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.07910791]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.07850785]
# year: 2017
# ----------------------------------------------
# threshold: [0.07850785]
# year: 2018
# ----------------------------------------------
# threshold: [0.07830783]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.08170817]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.08110811]
# year: 2017
# ----------------------------------------------
# threshold: [0.08110811]
# year: 2018
# ----------------------------------------------
# threshold: [0.08090809]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.08410841]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.08350835]
# year: 2017
# ----------------------------------------------
# threshold: [0.08360836]
# year: 2018
# ----------------------------------------------
# threshold: [0.08340834]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.08650865]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.0860086]
# year: 2017
# ----------------------------------------------
# threshold: [0.0860086]
# year: 2018
# ----------------------------------------------
# threshold: [0.08580858]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.08890889]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.08830883]
# year: 2017
# ----------------------------------------------
# threshold: [0.08830883]
# year: 2018
# ----------------------------------------------
# threshold: [0.08820882]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.09130913]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.09060906]
# year: 2017
# ----------------------------------------------
# threshold: [0.09070907]
# year: 2018
# ----------------------------------------------
# threshold: [0.09060906]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.09350935]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.0930093]
# year: 2017
# ----------------------------------------------
# threshold: [0.0930093]
# year: 2018
# ----------------------------------------------
# threshold: [0.09290929]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.09580958]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.09520952]
# year: 2017
# ----------------------------------------------
# threshold: [0.09520952]
# year: 2018
# ----------------------------------------------
# threshold: [0.09520952]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.0980098]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.09750975]
# year: 2017
# ----------------------------------------------
# threshold: [0.09740974]
# year: 2018
# ----------------------------------------------
# threshold: [0.09750975]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.10021002]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.09970997]
# year: 2017
# ----------------------------------------------
# threshold: [0.09970997]
# year: 2018
# ----------------------------------------------
# threshold: [0.09970997]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.10241024]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.1020102]
# year: 2017
# ----------------------------------------------
# threshold: [0.10191019]
# year: 2018
# ----------------------------------------------
# threshold: [0.10191019]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.10461046]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.10411041]
# year: 2017
# ----------------------------------------------
# threshold: [0.1040104]
# year: 2018
# ----------------------------------------------
# threshold: [0.10411041]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.10671067]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.10631063]
# year: 2017
# ----------------------------------------------
# threshold: [0.10621062]
# year: 2018
# ----------------------------------------------
# threshold: [0.10621062]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.10881088]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.10841084]
# year: 2017
# ----------------------------------------------
# threshold: [0.10831083]
# year: 2018
# ----------------------------------------------
# threshold: [0.10841084]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.1110111]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.11051105]
# year: 2017
# ----------------------------------------------
# threshold: [0.11051105]
# year: 2018
# ----------------------------------------------
# threshold: [0.11051105]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.11311131]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.11261126]
# year: 2017
# ----------------------------------------------
# threshold: [0.11261126]
# year: 2018
# ----------------------------------------------
# threshold: [0.11271127]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.11521152]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.11471147]
# year: 2017
# ----------------------------------------------
# threshold: [0.11471147]
# year: 2018
# ----------------------------------------------
# threshold: [0.11481148]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.11731173]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.11671167]
# year: 2017
# ----------------------------------------------
# threshold: [0.11671167]
# year: 2018
# ----------------------------------------------
# threshold: [0.11691169]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.11941194]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.11881188]
# year: 2017
# ----------------------------------------------
# threshold: [0.11881188]
# year: 2018
# ----------------------------------------------
# threshold: [0.1190119]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.12141214]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.12081208]
# year: 2017
# ----------------------------------------------
# threshold: [0.12091209]
# year: 2018
# ----------------------------------------------
# threshold: [0.12111211]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.12351235]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.12281228]
# year: 2017
# ----------------------------------------------
# threshold: [0.1230123]
# year: 2018
# ----------------------------------------------
# threshold: [0.12311231]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.12551255]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.12481248]
# year: 2017
# ----------------------------------------------
# threshold: [0.1250125]
# year: 2018
# ----------------------------------------------
# threshold: [0.12521252]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.12751275]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.12681268]
# year: 2017
# ----------------------------------------------
# threshold: [0.1270127]
# year: 2018
# ----------------------------------------------
# threshold: [0.12731273]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.12951295]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.12881288]
# year: 2017
# ----------------------------------------------
# threshold: [0.12911291]
# year: 2018
# ----------------------------------------------
# threshold: [0.12931293]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.13151315]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.13081308]
# year: 2017
# ----------------------------------------------
# threshold: [0.13121312]
# year: 2018
# ----------------------------------------------
# threshold: [0.13141314]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.13351335]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.13271327]
# year: 2017
# ----------------------------------------------
# threshold: [0.13321332]
# year: 2018
# ----------------------------------------------
# threshold: [0.13341334]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.13561356]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.13471347]
# year: 2017
# ----------------------------------------------
# threshold: [0.13521352]
# year: 2018
# ----------------------------------------------
# threshold: [0.13551355]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.13761376]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.13671367]
# year: 2017
# ----------------------------------------------
# threshold: [0.13731373]
# year: 2018
# ----------------------------------------------
# threshold: [0.13751375]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.13971397]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.13871387]
# year: 2017
# ----------------------------------------------
# threshold: [0.13931393]
# year: 2018
# ----------------------------------------------
# threshold: [0.13951395]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.14171417]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.14071407]
# year: 2017
# ----------------------------------------------
# threshold: [0.14141414]
# year: 2018
# ----------------------------------------------
# threshold: [0.14161416]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.14371437]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.14261426]
# year: 2017
# ----------------------------------------------
# threshold: [0.14341434]
# year: 2018
# ----------------------------------------------
# threshold: [0.14371437]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.14581458]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.14471447]
# year: 2017
# ----------------------------------------------
# threshold: [0.14551455]
# year: 2018
# ----------------------------------------------
# threshold: [0.14581458]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.14791479]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.14671467]
# year: 2017
# ----------------------------------------------
# threshold: [0.14751475]
# year: 2018
# ----------------------------------------------
# threshold: [0.14781478]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.150015]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.14871487]
# year: 2017
# ----------------------------------------------
# threshold: [0.14961496]
# year: 2018
# ----------------------------------------------
# threshold: [0.150015]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.15211521]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.15091509]
# year: 2017
# ----------------------------------------------
# threshold: [0.15161516]
# year: 2018
# ----------------------------------------------
# threshold: [0.15211521]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.15421542]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.1530153]
# year: 2017
# ----------------------------------------------
# threshold: [0.15371537]
# year: 2018
# ----------------------------------------------
# threshold: [0.15421542]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.15621562]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.1550155]
# year: 2017
# ----------------------------------------------
# threshold: [0.15581558]
# year: 2018
# ----------------------------------------------
# threshold: [0.15631563]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.15841584]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.15721572]
# year: 2017
# ----------------------------------------------
# threshold: [0.1580158]
# year: 2018
# ----------------------------------------------
# threshold: [0.15841584]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.16061606]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.15931593]
# year: 2017
# ----------------------------------------------
# threshold: [0.16021602]
# year: 2018
# ----------------------------------------------
# threshold: [0.16051605]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.16281628]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.16141614]
# year: 2017
# ----------------------------------------------
# threshold: [0.16231623]
# year: 2018
# ----------------------------------------------
# threshold: [0.16271627]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.1650165]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.16351635]
# year: 2017
# ----------------------------------------------
# threshold: [0.16451645]
# year: 2018
# ----------------------------------------------
# threshold: [0.16491649]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.16731673]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.16571657]
# year: 2017
# ----------------------------------------------
# threshold: [0.16671667]
# year: 2018
# ----------------------------------------------
# threshold: [0.1670167]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.16951695]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.16791679]
# year: 2017
# ----------------------------------------------
# threshold: [0.16891689]
# year: 2018
# ----------------------------------------------
# threshold: [0.16921692]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.17171717]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.17011701]
# year: 2017
# ----------------------------------------------
# threshold: [0.17111711]
# year: 2018
# ----------------------------------------------
# threshold: [0.17141714]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.1740174]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.17231723]
# year: 2017
# ----------------------------------------------
# threshold: [0.17331733]
# year: 2018
# ----------------------------------------------
# threshold: [0.17371737]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.17631763]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.17461746]
# year: 2017
# ----------------------------------------------
# threshold: [0.17571757]
# year: 2018
# ----------------------------------------------
# threshold: [0.1760176]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.17861786]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.17691769]
# year: 2017
# ----------------------------------------------
# threshold: [0.17791779]
# year: 2018
# ----------------------------------------------
# threshold: [0.17841784]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.1810181]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.17921792]
# year: 2017
# ----------------------------------------------
# threshold: [0.18031803]
# year: 2018
# ----------------------------------------------
# threshold: [0.18071807]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.18351835]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.18151815]
# year: 2017
# ----------------------------------------------
# threshold: [0.18271827]
# year: 2018
# ----------------------------------------------
# threshold: [0.18311831]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.1860186]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.18391839]
# year: 2017
# ----------------------------------------------
# threshold: [0.18511851]
# year: 2018
# ----------------------------------------------
# threshold: [0.18551855]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.18851885]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.18641864]
# year: 2017
# ----------------------------------------------
# threshold: [0.18761876]
# year: 2018
# ----------------------------------------------
# threshold: [0.1880188]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.19111911]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.1890189]
# year: 2017
# ----------------------------------------------
# threshold: [0.19011901]
# year: 2018
# ----------------------------------------------
# threshold: [0.19061906]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.19371937]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.19151915]
# year: 2017
# ----------------------------------------------
# threshold: [0.19271927]
# year: 2018
# ----------------------------------------------
# threshold: [0.19331933]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.19641964]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.19421942]
# year: 2017
# ----------------------------------------------
# threshold: [0.19541954]
# year: 2018
# ----------------------------------------------
# threshold: [0.19591959]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.19921992]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.1970197]
# year: 2017
# ----------------------------------------------
# threshold: [0.19821982]
# year: 2018
# ----------------------------------------------
# threshold: [0.19871987]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.2020202]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.19981998]
# year: 2017
# ----------------------------------------------
# threshold: [0.2010201]
# year: 2018
# ----------------------------------------------
# threshold: [0.20152015]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.20482048]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.20272027]
# year: 2017
# ----------------------------------------------
# threshold: [0.20392039]
# year: 2018
# ----------------------------------------------
# threshold: [0.20452045]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.20792079]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.20572057]
# year: 2017
# ----------------------------------------------
# threshold: [0.20692069]
# year: 2018
# ----------------------------------------------
# threshold: [0.20762076]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.21092109]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.20882088]
# year: 2017
# ----------------------------------------------
# threshold: [0.210021]
# year: 2018
# ----------------------------------------------
# threshold: [0.21082108]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.21412141]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.21192119]
# year: 2017
# ----------------------------------------------
# threshold: [0.21332133]
# year: 2018
# ----------------------------------------------
# threshold: [0.21412141]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.21742174]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.21512151]
# year: 2017
# ----------------------------------------------
# threshold: [0.21652165]
# year: 2018
# ----------------------------------------------
# threshold: [0.21742174]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.22082208]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.21862186]
# year: 2017
# ----------------------------------------------
# threshold: [0.220022]
# year: 2018
# ----------------------------------------------
# threshold: [0.22082208]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.22452245]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.22222222]
# year: 2017
# ----------------------------------------------
# threshold: [0.22352235]
# year: 2018
# ----------------------------------------------
# threshold: [0.22432243]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.22812281]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.22592259]
# year: 2017
# ----------------------------------------------
# threshold: [0.22722272]
# year: 2018
# ----------------------------------------------
# threshold: [0.22812281]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.2320232]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.22952295]
# year: 2017
# ----------------------------------------------
# threshold: [0.23112311]
# year: 2018
# ----------------------------------------------
# threshold: [0.23192319]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.23592359]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.23362336]
# year: 2017
# ----------------------------------------------
# threshold: [0.23512351]
# year: 2018
# ----------------------------------------------
# threshold: [0.2360236]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.23992399]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.23762376]
# year: 2017
# ----------------------------------------------
# threshold: [0.23922392]
# year: 2018
# ----------------------------------------------
# threshold: [0.24022402]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.24412441]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.24182418]
# year: 2017
# ----------------------------------------------
# threshold: [0.24352435]
# year: 2018
# ----------------------------------------------
# threshold: [0.24442444]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.24872487]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.24612461]
# year: 2017
# ----------------------------------------------
# threshold: [0.24792479]
# year: 2018
# ----------------------------------------------
# threshold: [0.2490249]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.25342534]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.25062506]
# year: 2017
# ----------------------------------------------
# threshold: [0.25262526]
# year: 2018
# ----------------------------------------------
# threshold: [0.25382538]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.25832583]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.25532553]
# year: 2017
# ----------------------------------------------
# threshold: [0.25762576]
# year: 2018
# ----------------------------------------------
# threshold: [0.25862586]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.26352635]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.26012601]
# year: 2017
# ----------------------------------------------
# threshold: [0.26242624]
# year: 2018
# ----------------------------------------------
# threshold: [0.26352635]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.26892689]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.26532653]
# year: 2017
# ----------------------------------------------
# threshold: [0.26772677]
# year: 2018
# ----------------------------------------------
# threshold: [0.26892689]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.27442744]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.27072707]
# year: 2017
# ----------------------------------------------
# threshold: [0.2730273]
# year: 2018
# ----------------------------------------------
# threshold: [0.27432743]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.28032803]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.27652765]
# year: 2017
# ----------------------------------------------
# threshold: [0.27882788]
# year: 2018
# ----------------------------------------------
# threshold: [0.28012801]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.28642864]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.28272827]
# year: 2017
# ----------------------------------------------
# threshold: [0.28512851]
# year: 2018
# ----------------------------------------------
# threshold: [0.28652865]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.29322932]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.28922892]
# year: 2017
# ----------------------------------------------
# threshold: [0.29182918]
# year: 2018
# ----------------------------------------------
# threshold: [0.29342934]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.30073007]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.29622962]
# year: 2017
# ----------------------------------------------
# threshold: [0.29892989]
# year: 2018
# ----------------------------------------------
# threshold: [0.30053005]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.30863086]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.3040304]
# year: 2017
# ----------------------------------------------
# threshold: [0.30683068]
# year: 2018
# ----------------------------------------------
# threshold: [0.30863086]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.31813181]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.31323132]
# year: 2017
# ----------------------------------------------
# threshold: [0.3160316]
# year: 2018
# ----------------------------------------------
# threshold: [0.31833183]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.32963296]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.32433243]
# year: 2017
# ----------------------------------------------
# threshold: [0.32743274]
# year: 2018
# ----------------------------------------------
# threshold: [0.33033303]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.34493449]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.33893389]
# year: 2017
# ----------------------------------------------
# threshold: [0.3420342]
# year: 2018
# ----------------------------------------------
# threshold: [0.34613461]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.36613661]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.35963596]
# year: 2017
# ----------------------------------------------
# threshold: [0.36183618]
# year: 2018
# ----------------------------------------------
# threshold: [0.3670367]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.39223922]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.38543854]
# year: 2017
# ----------------------------------------------
# threshold: [0.38773877]
# year: 2018
# ----------------------------------------------
# threshold: [0.39383938]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.42544254]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.41814181]
# year: 2017
# ----------------------------------------------
# threshold: [0.42054205]
# year: 2018
# ----------------------------------------------
# threshold: [0.42794279]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.47134713]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.46274627]
# year: 2017
# ----------------------------------------------
# threshold: [0.46544654]
# year: 2018
# ----------------------------------------------
# threshold: [0.47334733]
# year: 2016preVFP
# ----------------------------------------------
# threshold: [0.54175418]
# year: 2016postVFP
# ----------------------------------------------
# threshold: [0.5329533]
# year: 2017
# ----------------------------------------------
# threshold: [0.53445345]
# year: 2018
# ----------------------------------------------
# threshold: [0.5439544]

# %%
# import awkward as ak
# import copy

# A = ak.Array([1,2,3])
# B = ak.ones_like(A )
# A_zip = ak.zip({
#     "A" : A,
#     "B" : B
# })
# B_zip = copy.deepcopy(A_zip)
# C_zip = ak.concatenate([A_zip, B_zip])

# %%
from fitting import separateNfit
import pandas as pd
import numpy as np

years = [
    "2016preVFP",
    "2016postVFP",
    "2017",
    "2018",
]
stage2_out_name = "BDT_WgtON_original_AN_BDT_Sept27"
load_paths = {}
BDT_thresholds = {}
sig_eff = 0.45
for year in years:
    load_path = f"/work/users/yun79/stage2_output/{stage2_out_name}/ggh/{year}"
    load_paths[year] = load_path
    BDT_df = pd.read_csv(f"BDT_threshold_{year}.csv")
    bool_filter = np.isclose(BDT_df["sig_eff"], sig_eff)
    threshold = BDT_df["BDT_threshold"][bool_filter].values
    print(f"{year} threshold: {threshold}")
    BDT_thresholds[year] = [0, threshold, 1.0]
    
separateNfit(load_paths, BDT_thresholds)
# Out:
# 2016preVFP threshold: [0.16951695]
# 2016postVFP threshold: [0.16791679]
# 2017 threshold: [0.16891689]
# 2018 threshold: [0.16921692]
# separateNfit load_path: /work/users/yun79/stage2_output/BDT_WgtON_original_AN_BDT_Sept27/ggh/2016preVFP
# BDT_score :[0.104, 0.125, 0.0841, 0.128, 0.0917, ..., 0.21, 0.0698, 0.27, 0.438, 0.212]
# ak.max(BDT_score) :0.9089231491088867
# ak.min(BDT_score) :0.00261423597112298
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# BDT_score :[0.0888, 0.239, 0.0344, 0.0721, 0.0425, ..., 0.0882, 0.0828, 0.146, 0.189]
# ak.max(BDT_score) :0.8770337104797363
# ak.min(BDT_score) :0.0007012422429397702
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# separateNfit load_path: /work/users/yun79/stage2_output/BDT_WgtON_original_AN_BDT_Sept27/ggh/2016postVFP
# BDT_score :[0.216, 0.0831, 0.2, 0.179, 0.0811, ..., 0.157, 0.093, 0.209, 0.188, 0.194]
# ak.max(BDT_score) :0.8894630670547485
# ak.min(BDT_score) :0.0025116296019405127
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# BDT_score :[0.149, 0.0467, 0.0398, 0.136, 0.161, ..., 0.207, 0.0657, 0.078, 0.178, 0.275]
# ak.max(BDT_score) :0.8937320113182068
# ak.min(BDT_score) :0.0006646885885857046
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# separateNfit load_path: /work/users/yun79/stage2_output/BDT_WgtON_original_AN_BDT_Sept27/ggh/2017
# BDT_score :[0.251, 0.0382, 0.125, 0.19, 0.115, ..., 0.445, 0.277, 0.165, 0.143, 0.219]
# ak.max(BDT_score) :0.919155478477478
# ak.min(BDT_score) :0.0020535129588097334
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# BDT_score :[0.0588, 0.171, 0.0561, 0.128, 0.206, ..., 0.163, 0.0615, 0.164, 0.0693, 0.122]
# ak.max(BDT_score) :0.8667632937431335
# ak.min(BDT_score) :0.0007841766928322613
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# separateNfit load_path: /work/users/yun79/stage2_output/BDT_WgtON_original_AN_BDT_Sept27/ggh/2018
# BDT_score :[0.162, 0.195, 0.173, 0.108, 0.0821, ..., 0.156, 0.205, 0.204, 0.0946, 0.303]
# ak.max(BDT_score) :0.9196866154670715
# ak.min(BDT_score) :0.002296607941389084
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# BDT_score :[0.22, 0.274, 0.136, 0.104, 0.234, ..., 0.198, 0.219, 0.164, 0.0723, 0.242]
# ak.max(BDT_score) :0.877716600894928
# ak.min(BDT_score) :0.0009443535818718374
# ak.sum(subCat_idx==-1): 0
# ak.min(subCat_idx): 0.0
# ak.max(subCat_idx): 1.0
# bkg_event_l: [<Array [{dimuon_mass: 118, ...}, ..., {...}] type='10002975 * {dimuon_mass:...'>, <Array [{dimuon_mass: 128, ...}, ..., {...}] type='10585012 * {dimuon_mass:...'>, <Array [{dimuon_mass: 142, ...}, ..., {...}] type='10540641 * {dimuon_mass:...'>, <Array [{dimuon_mass: 120, ...}, ..., {...}] type='10736495 * {dimuon_mass:...'>]
# sig_event_l: [<Array [{dimuon_mass: 124, ...}, ..., {...}] type='642947 * {dimuon_mass: f...'>, <Array [{dimuon_mass: 126, ...}, ..., {...}] type='633438 * {dimuon_mass: f...'>, <Array [{dimuon_mass: 122, ...}, ..., {...}] type='1277797 * {dimuon_mass: ...'>, <Array [{dimuon_mass: 121, ...}, ..., {...}] type='1302254 * {dimuon_mass: ...'>]
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       109393127.9 Edm =       39428.76175 NCalls =     17
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 109393127.9
#   Edm           : 39428.76175
#   Internal parameters:	[     0.6727023301  -0.001684318905    -0.1409596604]
#   Internal gradient  :	[      211186.8196      417998332.7     -227650.6606]
#   Internal covariance matrix:
# [[  9.0800984e-08              0              0]
#  [              0  8.5713212e-13              0]
#  [              0              0   7.534956e-08]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 1500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       109393127.9 Edm =       39428.76175 NCalls =     17
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       109392121.9 Edm =     0.03225962518 NCalls =     33
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       109392121.9 Edm =     0.02060022297 NCalls =     41
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       109392120.7 Edm =    0.005309490248 NCalls =     52
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       109392120.7 Edm =   0.0003013216035 NCalls =     59
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00321659
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =       109392120.7 Edm =      0.3390096012 NCalls =     77
# Warning in <Minuit2>: VariableMetricBuilder Reached machine accuracy limit; Edm 0.33901 is smaller than machine limit 6.52028 while 0.001 was requested
# Warning in <Minuit2>: VariableMetricBuilder No convergence; Edm 0.33901 is above tolerance 0.01
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Minimization did NOT converge, Edm is above max
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 1500
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00303542
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is full but made positive defined
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       109392120.7 Edm =    0.001879625504 NCalls =      7
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 109392120.7
#   Edm           : 0.001879625504
#   Internal parameters:	[     0.6694965672  -0.001707548631    -0.1420867882]
#   Internal gradient  :	[     -39.85904331     -92036.70209      41.64602368]
#   Internal covariance matrix:
# [[  9.0225545e-08              0              0]
#  [              0    8.55181e-13              0]
#  [              0              0  7.5604901e-08]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 1500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       109392120.7 Edm =    0.001879625504 NCalls =      7
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       109392120.7 Edm =    0.002305436927 NCalls =     15
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       109392120.6 Edm =     0.04996427272 NCalls =     26
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       109392120.5 Edm =    0.002655130836 NCalls =     35
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =
# Info in <Minuit2>: VariableMetricBuilder   17 - FCN =       37789309.79 Edm =       1.251834404 NCalls =    184
# Info in <Minuit2>: VariableMetricBuilder   18 - FCN =       37789308.05 Edm =      0.3065719989 NCalls =    193
# Info in <Minuit2>: VariableMetricBuilder   19 - FCN =       37789307.55 Edm =      0.6502545206 NCalls =    202
# Info in <Minuit2>: VariableMetricBuilder   20 - FCN =       37789305.24 Edm =      0.5638988737 NCalls =    214
# Info in <Minuit2>: VariableMetricBuilder   21 - FCN =       37789304.86 Edm =      0.8156540505 NCalls =    222
# Info in <Minuit2>: VariableMetricBuilder   22 - FCN =       37789304.54 Edm =     0.06071301786 NCalls =    231
# Info in <Minuit2>: VariableMetricBuilder   23 - FCN =        37789304.3 Edm =      0.1240033695 NCalls =    241
# Info in <Minuit2>: VariableMetricBuilder   24 - FCN =       37789304.19 Edm =     0.02857793716 NCalls =    249
# Info in <Minuit2>: VariableMetricBuilder   25 - FCN =       37789304.14 Edm =    0.008031311087 NCalls =    260
# Info in <Minuit2>: VariableMetricBuilder   26 - FCN =       37789304.13 Edm =   0.0007399055772 NCalls =    269
# Info in <Minuit2>: VariableMetricBuilder   27 - FCN =       37789304.13 Edm =    0.001562903996 NCalls =    278
# Info in <Minuit2>: VariableMetricBuilder   28 - FCN =       37789304.13 Edm =      0.0018073566 NCalls =    288
# Warning in <Minuit2>: VariableMetricBuilder No improvement in line search
# Info in <Minuit2>: VariableMetricBuilder   29 - FCN =       37789304.13 Edm =      0.0018073566 NCalls =    299
# Info in <Minuit2>: VariableMetricBuilder Edm is close to limit - return current minimum
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00367724
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder   30 - FCN =       37789304.13 Edm =   0.0008591411163 NCalls =    315
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Covar was made pos def
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 1500
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00310573
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is full but made positive defined
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       37789304.13 Edm =    0.002583611756 NCalls =      9
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 37789304.13
#   Edm           : 0.002583611756
#   Internal parameters:	[     0.2443265548 -0.0006006123769    -0.3234118911]
#   Internal gradient  :	[      136.3698536      40533.75653     -118.9823562]
#   Internal covariance matrix:
# [[  1.6661339e-07              0              0]
#  [              0   2.407342e-12              0]
#  [              0              0  2.3174401e-07]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 1500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       37789304.13 Edm =    0.002583611756 NCalls =      9
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       37789304.13 Edm =   6.696425667e-07 NCalls =     17
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00367543
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       37789304.13 Edm =    6.33652858e-05 NCalls =     37
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Covar was made pos def
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 1500
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00304509
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is full but made positive defined
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(subCat0_BWZ_Redux_over_subCat0_BWZ_Redux_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_subCat0_BWZ_Redux_over_subCat0_BWZ_Redux_Int[mh_ggh]_subCat0_rooHist_BWZRedux) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 1500 convergence for edm < 1 strategy 1
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(subCat0_BWZ_Redux_Int[mh_ggh]) using numeric integrator RooIntegrator1D to calculate Int(mh_ggh)
# Minuit2Minimizer : Invalid minimum - status = 3
# FVAL  = 1.09392e+08
# Edm   = 0.33901
# Nfcn  = 77
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(subCat0_BWZ_Redux_over_subCat0_BWZ_Redux_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_subCat0_BWZ_Redux_over_subCat0_BWZ_Redux_Int[mh_ggh]_subCat0_rooHist_BWZRedux) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 1500 convergence for edm < 1 strategy 1
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(subCat0_BWZ_Redux_Int[mh_ggh]) using numeric integrator RooIntegrator1D to calculate Int(mh_ggh)
# Minuit2Minimizer : Valid minimum - status = 1
# FVAL  = 109392077.506363675
# Edm   = 0.000343173702378997468
# Nfcn  = 248
# BWZ_Redux_a_coeff_subCat0	  = 0.0369002	 +/-  0.000237997	(limited)
# BWZ_Redux_b_coeff_subCat0	  = -9.46929e-05	 +/-  7.72816e-07	(limited)
# BWZ_Redux_c_coeff_subCat0	  = 1.97707	 +/-  0.00307838	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(subCat1_BWZ_Redux_over_subCat1_BWZ_Redux_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_subCat1_BWZ_Redux_over_subCat1_BWZ_Redux_Int[mh_ggh]_subCat1_rooHist_BWZRedux) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 1500 convergence for edm < 1 strategy 1
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(subCat1_BWZ_Redux_Int[mh_ggh]) using numeric integrator RooIntegrator1D to calculate Int(mh_ggh)
# Minuit2Minimizer : Valid minimum - status = 1
# FVAL  = 37789304.1271478608
# Edm   = 0.000859141116304842933
# Nfcn  = 315
# BWZ_Redux_a_coeff_subCat1	  = 0.0241903	 +/-  0.000400618	(limited)
# BWZ_Redux_b_coeff_subCat1	  = -6.00612e-05	 +/-  1.2938e-06	(limited)
# BWZ_Redux_c_coeff_subCat1	  = 1.70549	 +/-  0.00518837	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(subCat1_BWZ_Redux_over_subCat1_BWZ_Redux_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_subCat1_BWZ_Redux_over_subCat1_BWZ_Redux_Int[mh_ggh]_subCat1_rooHist_BWZRedux) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 1500 convergence for edm < 1 strategy 1
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(subCat1_BWZ_Redux_Int[mh_ggh]) using numeric integrator RooIntegrator1D to calculate Int(mh_ggh)
# Minuit2Minimizer : Valid minimum - status = 1
# FVAL  = 37789304.1263488382
# Edm   = 6.33652858007331102e-05
# Nfcn  = 37
# BWZ_Redux_a_coeff_subCat1	  = 0.0241899	 +/-  0.000400613	(limited)
# BWZ_Redux_b_coeff_subCat1	  = -6.00628e-05	 +/-  1.29386e-06	(limited)
# BWZ_Redux_c_coeff_subCat1	  = 1.7055	 +/-  0.00518804	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# signal_subCat0 norm_val: 484.93750047818736
# signal_subCat1 norm_val: 396.5934434301593
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(signal_subCat0_over_signal_subCat0_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(signal_subCat0): WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303)."
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_signal_subCat0_over_signal_subCat0_Int[mh_ggh]_subCat0_rooHist_signal) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3000 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 1132.09398432820149
# Edm   = 8.48278604294132751e-06
# Nfcn  = 197
# MH	  = 124.806	 +/-  0.117086	(limited)
# alpha1_subCat0	  = 1.32131	 +/-  0.285678	(limited)
# alpha2_subCat0	  = 1.52448	 +/-  0.360124	(limited)
# n1_subCat0	  = 2.35353	 +/-  1.14972	(limited)
# n2_subCat0	  = 5.69472	 +/-  4.23079	(limited)
# sigma_subCat0	  = 1.68347	 +/-  0.150033	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(signal_subCat0_over_signal_subCat0_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(signal_subCat0): WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303)."
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_signal_subCat0_over_signal_subCat0_Int[mh_ggh]_subCat0_rooHist_signal) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3000 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 1132.09398293012259
# Edm   = 1.04051097305698076e-05
# Nfcn  = 83
# MH	  = 124.806	 +/-  0.120178	(limited)
# alpha1_subCat0	  = 1.32139	 +/-  0.320589	(limited)
# alpha2_subCat0	  = 1.52454	 +/-  0.37025	(limited)
# n1_subCat0	  = 2.35376	 +/-  1.24274	(limited)
# n2_subCat0	  = 5.6943	 +/-  4.14156	(limited)
# sigma_subCat0	  = 1.68345	 +/-  0.16525	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(signal_subCat1_over_signal_subCat1_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(signal_subCat1): WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303)."
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_signal_subCat1_over_signal_subCat1_Int[mh_ggh]_subCat1_rooHist_signal) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3000 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 823.239363728801322
# Edm   = 0.000273072481352436877
# Nfcn  = 169
# MH	  = 124.873	 +/-  0.0907352	(limited)
# alpha1_subCat1	  = 1.51613	 +/-  0.28763	(limited)
# alpha2_subCat1	  = 1.85321	 +/-  0.439894	(limited)
# n1_subCat1	  = 1.80809	 +/-  0.765955	(limited)
# n2_subCat1	  = 3.9448	 +/-  2.72624	(limited)
# sigma_subCat1	  = 1.33585	 +/-  0.102533	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(signal_subCat1_over_signal_subCat1_Int[mh_ggh]) fixing normalization set for coefficient determination to observables in data
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(signal_subCat1): WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303)."
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_signal_subCat1_over_signal_subCat1_Int[mh_ggh]_subCat1_rooHist_signal) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3000 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 823.239294940335071
# Edm   = 0.000206239841964193558
# Nfcn  = 77
# MH	  = 124.873	 +/-  0.0908082	(limited)
# alpha1_subCat1	  = 1.51689	 +/-  0.288979	(limited)
# alpha2_subCat1	  = 1.85183	 +/-  0.434758	(limited)
# n1_subCat1	  = 1.80838	 +/-  0.769697	(limited)
# n2_subCat1	  = 3.95514	 +/-  2.71843	(limited)
# sigma_subCat1	  = 1.33549	 +/-  0.102091	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       1135.377418 Edm =        4.08084681 NCalls =     23
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 1135.377418
#   Edm           : 4.08084681
#   Internal parameters:	[   -0.03900989327     -1.307670934     -1.286628773     -1.167552078    -0.9284592379    -0.1167780589]
#   Internal gradient  :	[      13.27880773      -64.6269692     -117.0159267    -0.2472649363     -4.295215754      48.07702751]
#   Internal covariance matrix:
# [[  0.00083659957              0              0              0              0              0]
#  [              0  0.00017944326              0              0              0              0]
#  [              0              0  0.00028736631              0              0              0]
#  [              0              0              0   0.0049417531              0              0]
#  [              0              0              0              0    0.039912575              0]
#  [              0              0              0              0              0   0.0046529921]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 3000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       1135.377418 Edm =        4.08084681 NCalls =     23
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       1133.275988 Edm =      0.4211755969 NCalls =     39
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       1132.675905 Edm =      0.4738331936 NCalls =     56
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       1132.305184 Edm =     0.04388755082 NCalls =     73
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       1132.265424 Edm =     0.01438898302 NCalls =     87
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =        1132.22668 Edm =     0.02965206063 NCalls =    101
# Info in <Minuit2>: VariableMetricBuilder    6 - FCN =       1132.138008 Edm =       0.052585552 NCalls =    115
# Info in <Minuit2>: VariableMetricBuilder    7 - FCN =       1132.097248 Edm =    0.001866555377 NCalls =    129
# Info in <Minuit2>: VariableMetricBuilder    8 - FCN
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3000
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is accurate
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(subCat0_BWZ_Redux_Int[mh_ggh]) using numeric integrator RooIntegrator1D to calculate Int(mh_ggh)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(subCat1_BWZ_Redux_Int[mh_ggh]) using numeric integrator RooIntegrator1D to calculate Int(mh_ggh)
# Info in <TCanvas::Print>: pdf file ./quick_plots//bkgMC_plot_subCat0.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: pdf file ./quick_plots//bkgMC_plot_subCat1.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: pdf file ./quick_plots//sigMC_plot_subCat0.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: pdf file ./quick_plots//sigMC_plot_subCat1.pdf has been created
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::data_cat0_ggh_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset data_cat0_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::mh_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::bkg_cat0_ggh_pdf_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooModZPdf::bkg_cat0_ggh_pdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::BWZ_Redux_a_coeff_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::BWZ_Redux_b_coeff_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::BWZ_Redux_c_coeff_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::ggH_cat0_ggh_pdf_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCrystalBall::ggH_cat0_ggh_pdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::mh_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooFormulaVar::ggH_cat0_ggh_fpeak
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::MH
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::CMS_hmm_peak_cat0_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooFormulaVar::ggH_cat0_ggh_fsigma
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::sigma_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::CMS_hmm_sigma_cat0_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::alpha1_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::n1_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::alpha2_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::n2_subCat0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset data_ggH_cat0_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::data_cat1_ggh_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset data_cat1_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::mh_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::bkg_cat1_ggh_pdf_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooModZPdf::bkg_cat1_ggh_pdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::BWZ_Redux_a_coeff_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::BWZ_Redux_b_coeff_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::BWZ_Redux_c_coeff_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::ggH_cat1_ggh_pdf_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCrystalBall::ggH_cat1_ggh_pdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::mh_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooFormulaVar::ggH_cat1_ggh_fpeak
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::MH
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::CMS_hmm_peak_cat1_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooFormulaVar::ggH_cat1_ggh_fsigma
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::sigma_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::CMS_hmm_sigma_cat1_ggh
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::alpha1_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::n1_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::alpha2_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::n2_subCat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset data_ggH_cat1_ggh

# %%
# %%bash
# combineCards.py datacard_cat0_ggh.txt datacard_cat1_ggh.txt >  datacard_comb_sig_all_ggh_test.txt

# %%
# %%bash
# text2workspace.py -m 125 datacard_comb_sig_all_ggh_test.txt
# combine -M Significance -d datacard_comb_sig_all_ggh_test.root -m 125 -n _signif_all_ggh --cminDefaultMinimizerStrategy=1 -t -1 --toysFrequentist --expectSignal 1 --X-rtd FITTER_NEWER_GIVE_UP --X-rtd FITTER_BOUND --setParameters pdf_index_ggh=0 --cminRunAllDiscreteCombinations --setParameterRanges r=-10,10 --X-rtd MINIMIZER_freezeDisassociatedParams --cminDefaultMinimizerTolerance 0.01 --X-rtd MINIMIZER_MaxCalls=9999999 --X-rtd FAST_VERTICAL_MORPH
# Out:
#  <<< Combine >>>
#  <<< v10.0.1 >>>
# >>> Random number generator seed is 123456
# >>> Method used is Significance
# Set Range of Parameter r To : (-10,10)
# Warning: Did not find a parameter with name pdf_index_ggh
#
#  -- Significance --
# Significance: 0.164338
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
import subprocess
ans = subprocess.run(["combineCards.py", "datacard_cat0_ggh.txt", "datacard_cat1_ggh.txt"], capture_output=True)
with open("datacard_comb_sig_all_ggh_test.txt", "w") as text_file:
     subprocess.call(["combineCards.py", "datacard_cat0_ggh.txt", "datacard_cat1_ggh.txt"], stdout=text_file)

# %%
(str(ans.stdout))
# Out:
# "b'Combination of datacard_cat0_ggh.txt  datacard_cat1_ggh.txt\\nimax 2 number of bins\\njmax 1 number of processes minus 1\\nkmax 65 number of nuisance parameters\\n----------------------------------------------------------------------------------------------------------------------------------\\nshapes bkg       ch1       workspace/workspace_bkg_cat0_ggh.root w:bkg_cat0_ggh_pdf\\nshapes data_obs  ch1       workspace/workspace_bkg_cat0_ggh.root w:data_cat0_ggh\\nshapes ggH_hmm   ch1       workspace/workspace_sig_cat0_ggh.root w:ggH_cat0_ggh_pdf\\nshapes bkg       ch2       workspace/workspace_bkg_cat1_ggh.root w:bkg_cat1_ggh_pdf\\nshapes data_obs  ch2       workspace/workspace_bkg_cat1_ggh.root w:data_cat1_ggh\\nshapes ggH_hmm   ch2       workspace/workspace_sig_cat1_ggh.root w:ggH_cat1_ggh_pdf\\n----------------------------------------------------------------------------------------------------------------------------------\\nbin          ch1          ch2        \\nobservation  -1           -1         \\n----------------------------------------------------------------------------------------------------------------------------------\\nbin                                                ch1          ch1          ch2          ch2        \\nprocess                                            ggH_hmm      bkg          ggH_hmm      bkg        \\nprocess                                            0            1            0            1          \\nrate                                               1            1            1            1          \\n----------------------------------------------------------------------------------------------------------------------------------\\nBR_mm                   lnN                        1.012        -            1.012        -          \\nCMS_eff_m               lnN                        0.994/1.006  -            0.994/1.006  -          \\nCMS_pileup_2016         lnN                        1/1          -            1/1          -          \\nCMS_pileup_2017         lnN                        1/1          -            1/1          -          \\nCMS_pileup_2018         lnN                        1.001/0.999  -            1.001/0.999  -          \\nCMS_prefiring_2016      lnN                        1.001/0.999  -            1.001/0.999  -          \\nCMS_prefiring_2017      lnN                        1.001/0.999  -            1.001/0.999  -          \\nCMS_ps                  lnN                        1.044/0.975  -            1.044/0.975  -          \\nCMS_res_j_barrel_2016   lnN                        1/0.999      -            1/0.999      -          \\nCMS_res_j_barrel_2017   lnN                        1/1.001      -            1/1.001      -          \\nCMS_res_j_barrel_2018   lnN                        1/1.002      -            1/1.002      -          \\nCMS_res_j_endcap1_2016   lnN                       1/1.001      -            1/1.001      -          \\nCMS_res_j_endcap1_2017   lnN                       1/1          -            1/1          -          \\nCMS_res_j_endcap1_2018   lnN                       1/1          -            1/1          -          \\nCMS_res_j_endcap2highpt_2016   lnN                 1/1          -            1/1          -          \\nCMS_res_j_endcap2highpt_2017   lnN                 1/1          -            1/1          -          \\nCMS_res_j_endcap2highpt_2018   lnN                 1/1          -            1/1          -          \\nCMS_res_j_endcap2lowpt_2016   lnN                  1/0.999      -            1/0.999      -          \\nCMS_res_j_endcap2lowpt_2017   lnN                  1/1          -            1/1          -          \\nCMS_res_j_endcap2lowpt_2018   lnN                  1/0.999      -            1/0.999      -          \\nCMS_res_j_forwardhighpt_2016   lnN                 1/1          -            1/1          -          \\nCMS_res_j_forwardhighpt_2017   lnN                 1/1          -            1/1          -          \\nCMS_res_ ...
